# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as plt
import datetime 
# %matplotlib inline
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

import matplotlib.pyplot as plt
# %matplotlib inline

import platform
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from matplotlib import font_manager, rc
from matplotlib import style

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
nba_retire = pd.read_csv('nba_df.csv')

# %%
nba_all = pd.read_csv('all_seasons.csv')
nba_all.drop('Unnamed: 0',axis=1,inplace=True)
nba_all.head()
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12      99.790240
# 1  Dwayne Schintzius               LAC  28.0         215.90     117.933920
# 2       Earl Cureton               TOR  39.0         205.74      95.254320
# 3        Ed O'Bannon               DAL  24.0         203.20     100.697424
# 4        Ed Pinckney               MIA  34.0         205.74     108.862080
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1                      Florida     USA       1990           1           24
# 2                Detroit Mercy     USA       1979           3           58
# 3                         UCLA     USA       1995           1            9
# 4                    Villanova     USA       1985           1           10
#
#     ...     pts   reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  \
# 0   ...     5.7  16.1  3.1        16.1     0.186     0.323    0.100   0.479
# 1   ...     2.3   1.5  0.3        12.3     0.078     0.151    0.175   0.430
# 2   ...     0.8   1.0  0.4        -2.1     0.105     0.102    0.103   0.376
# 3   ...     3.7   2.3  0.6        -8.7     0.060     0.149    0.167   0.399
# 4   ...     2.4   2.4  0.2       -11.2     0.109     0.179    0.127   0.611
#
#    ast_pct   season
# 0    0.113  1996-97
# 1    0.048  1996-97
# 2    0.148  1996-97
# 3    0.077  1996-97
# 4    0.040  1996-97
#
# [5 rows x 21 columns]

# %%
nba_injury = pd.read_csv('nba_injury_1998.csv')
nba_injury.rename({'Relinquished':'name'},axis=1,inplace=True)

# %%
def info(df):
    display(df.describe())
    display(df.info())
    display(df.isna().sum())

# %%
info(nba_all)
# Out:
#          Unnamed: 0           age  player_height  player_weight            gp  \
# count  11145.000000  11145.000000   11145.000000   11145.000000  11145.000000
# mean    5572.000000     27.168686     200.812818     100.637868     52.005832
# std     3217.428709      4.344164       9.190973      12.576295     25.069495
# min        0.000000     18.000000     160.020000      60.327736      1.000000
# 25%     2786.000000     24.000000     195.580000      90.718400     32.000000
# 50%     5572.000000     27.000000     200.660000      99.790240     58.000000
# 75%     8358.000000     30.000000     208.280000     109.315672     74.000000
# max    11144.000000     44.000000     231.140000     163.293120     85.000000
#
#                 pts           reb           ast    net_rating      oreb_pct  \
# count  11145.000000  11145.000000  11145.000000  11145.000000  11145.000000
# mean       8.126487      3.560036      1.801463     -2.153899      0.055593
# std        5.935482      2.495394      1.789940     12.150611      0.043889
# min        0.000000      0.000000      0.000000   -200.000000      0.000000
# 25%        3.500000      1.800000      0.600000     -6.300000      0.022000
# 50%        6.600000      3.000000      1.200000     -1.300000      0.043000
# 75%       11.500000      4.700000      2.400000      3.200000      0.086000
# max       36.100000     16.300000     11.700000    300.000000      1.000000
#
#            dreb_pct       usg_pct        ts_pct       ast_pct
# count  11145.000000  11145.000000  11145.000000  11145.000000
# mean       0.141772      0.185599      0.508099      0.131078
# std        0.063194      0.053047      0.098879      0.095017
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.096000      0.150000      0.478000      0.065000
# 50%        0.132000      0.182000      0.521000      0.102000
# 75%        0.182000      0.218000      0.557000      0.178000
# max        1.000000      1.000000      1.500000      1.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11145 entries, 0 to 11144
# Data columns (total 22 columns):
# Unnamed: 0           11145 non-null int64
# player_name          11145 non-null object
# team_abbreviation    11145 non-null object
# age                  11145 non-null float64
# player_height        11145 non-null float64
# player_weight        11145 non-null float64
# college              11145 non-null object
# country              11145 non-null object
# draft_year           11145 non-null object
# draft_round          11145 non-null object
# draft_number         11145 non-null object
# gp                   11145 non-null int64
# pts                  11145 non-null float64
# reb                  11145 non-null float64
# ast                  11145 non-null float64
# net_rating           11145 non-null float64
# oreb_pct             11145 non-null float64
# dreb_pct             11145 non-null float64
# usg_pct              11145 non-null float64
# ts_pct               11145 non-null float64
# ast_pct              11145 non-null float64
# season               11145 non-null object
# dtypes: float64(12), int64(2), object(8)
# memory usage: 1.9+ MB
# None
# Unnamed: 0           0
# player_name          0
# team_abbreviation    0
# age                  0
# player_height        0
# player_weight        0
# college              0
# country              0
# draft_year           0
# draft_round          0
# draft_number         0
# gp                   0
# pts                  0
# reb                  0
# ast                  0
# net_rating           0
# oreb_pct             0
# dreb_pct             0
# usg_pct              0
# ts_pct               0
# ast_pct              0
# season               0
# dtype: int64

# %%
info(nba_injury)
# Out:
#               Date   Team           Relinquished         Notes        Notes2
# count        13379  13379                  13379         13379         13379
# unique        3291     33                   1873          2033          1975
# top     2006-10-31  Spurs  (William) Tony Parker  placed on IL  placed on IL
# freq            73    604                     50          5138          5138
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13379 entries, 0 to 13378
# Data columns (total 5 columns):
# Date            13379 non-null object
# Team            13379 non-null object
# Relinquished    13379 non-null object
# Notes           13379 non-null object
# Notes2          13379 non-null object
# dtypes: object(5)
# memory usage: 522.7+ KB
# None
# Date            0
# Team            0
# Relinquished    0
# Notes           0
# Notes2          0
# dtype: int64

# %%
# 은퇴  시즌이 2개인 선수들
name_list = nba_retire.groupby(['name']).count().sort_values('age',ascending=False)
name_list = list(name_list[name_list['age'] == 2].index)
name_list
# Out:
# ['Keyon Dooling',
#  'Rasheed Wallace',
#  'Elton Brand',
#  'Nazr Mohammed',
#  'Brandon Roy',
#  'Nick Collison',
#  'Boštjan Nachbar']

# %%
# 은퇴 시즌이 2개인 선수들 1개로 만들기
index_list = []
while len(name_list) > 0:
    cnt = len(name_list)
    for idx, value in nba_retire.iterrows():
        if value[0] in name_list:
            index_list.append(idx)
            name_list.remove(value[0]) 
nba_retire = nba_retire.drop(index_list).reset_index(drop=True)
nba_retire
# Out:
#                      name  age  season
# 0             Kevin Ollie   37    2010
# 1            Adonal Foyle   35    2010
# 2         Fabricio Oberto   35    2010
# 3           Steve Francis   33    2010
# 4          Robert Traylor   34    2010
# 5          Jason Williams   35    2011
# 6          Jarron Collins   32    2011
# 7        Shaquille O'Neal   39    2011
# 8          Trajan Langdon   35    2011
# 9                Yao Ming   30    2011
# 10    Radoslav Nesterović   35    2011
# 11          Travis Hansen   33    2011
# 12     Žydrūnas Ilgauskas   36    2011
# 13             Dan Dickau   33    2011
# 14             Sean Marks   36    2011
# 15        Peja Stojaković   34    2011
# 16        Antonio McDyess   37    2011
# 17           Theo Ratliff   38    2011
# 18          Greg Ostertag   38    2011
# 19             T. J. Ford   28    2011
# 20            Jeff Foster   35    2011
# 21         Antoine Walker   35    2011
# 22         Anthony Parker   37    2012
# 23         Eduardo Nájera   36    2012
# 24              Ime Udoka   35    2012
# 25           Laron Profit   35    2012
# 26       Brian Scalabrine   34    2012
# 27            Brad Miller   36    2012
# 28            Mehmet Okur   33    2012
# 29         Brian Cardinal   36    2012
# ..                    ...  ...     ...
# 146       Mirza Teletović   33    2018
# 147     Richard Jefferson   38    2018
# 148          Ronnie Price   35    2018
# 149          Al Jefferson   34    2018
# 150        Kris Humphries   34    2018
# 151  Gerald Henderson Jr.   31    2018
# 152         Channing Frye   36    2019
# 153           Dwyane Wade   37    2019
# 154         Dirk Nowitzki   40    2019
# 155           Tony Parker   37    2019
# 156       Darren Collison   31    2019
# 157             Gary Neal   34    2019
# 158         Zaza Pachulia   35    2019
# 159      Shaun Livingston   34    2019
# 160           Jason Terry   42    2019
# 161             Luol Deng   34    2019
# 162         José Calderón   38    2019
# 163         Zach Randolph   38    2019
# 164         Marcin Gortat   36    2019
# 165         Trevor Booker   32    2019
# 166             Jon Leuer   31    2019
# 167          Vince Carter   43    2019
# 168       Marvin Williams   34    2020
# 169       Leandro Barbosa   37    2020
# 170        Kevin Séraphin   30    2020
# 171          Corey Brewer   34    2020
# 172         Dorell Wright   34    2020
# 173          Aaron Brooks   35    2020
# 174          Andrew Bogut   36    2020
# 175           Evan Turner   32    2020
#
# [176 rows x 3 columns]

# %%
# 몇 시즌 뛰었는지 계산
nba_player = nba_all.groupby('player_name',as_index=False).agg({'season':'count'}).sort_values('season',ascending=False).reset_index(drop=True)

# %%
# nba은퇴자랑 player 시즌 머지
nba_01 = pd.merge(nba_retire, nba_player, left_on='name', right_on='player_name',how='left').sort_values('season_y').reset_index(drop=True)
nba_01 = nba_01.drop(['season_x','player_name'],axis=1).rename({'season_y':'season'},axis=1)
# 이름 달라서 그거 바꿔주기
name_list = ['Rasho Nesterovic','Zydrunas Ilgauskas','Peja Stojakovic','T.J. Ford','Eduardo Najera','Vladimir Stepania','Darko Milicic',
             'Hedo Turkoglu','Kosta Perovic','Raul Lopez','Andres Nocioni','Primoz Brezec','Bostjan Nachbar','Jiri Welsch',
            'PJ Hairston','Manu Ginobili','Mike Dunleavy','Mirza Teletovic','Gerald Henderson','Jose Calderon','Kevin Seraphin']
cnt = 0
for i in range(155,176):
    nba_01.loc[i,'name'] = name_list[cnt]
    cnt += 1

# %%
# nba은퇴자 이름 바꿔서 다시 명단이랑 player 머지
nba_02 = pd.merge(nba_01, nba_player, left_on='name', right_on='player_name').drop(['season_x','player_name'],axis=1).rename({'season_y':'season'},axis=1)

# %%
nba_injury_sum = nba_injury.groupby('name', as_index=False).agg({'Notes':'count'}).sort_values('Notes',ascending=False).reset_index(drop=True)
nba_injury_sum
# Out:
#                                                name  Notes
# 0                             (William) Tony Parker     50
# 1                  Emanuel Ginobili / Manu Ginobili     44
# 2                                       Dwyane Wade     43
# 3                                        C.J. Miles     37
# 4                                      Andrew Bogut     36
# 5                                     Bruno Caboclo     35
# 6                                      Devin Harris     35
# 7                                     Kawhi Leonard     35
# 8                                        Sean Marks     35
# 9                                        Melvin Ely     35
# 10                                    Travis Diener     34
# 11                                   Tyson Chandler     33
# 12                                 Chandler Parsons     33
# 13                                  Wilson Chandler     33
# 14                                  Jermaine O'Neal     32
# 15                                   Andre Iguodala     32
# 16                                   Brian Cardinal     30
# 17           Nene / Nene Hilario / Maybyner Hilario     29
# 18                                      Steve Novak     29
# 19                                   Eduardo Najera     28
# 20                                     Maurice Ager     28
# 21                                     Kyrie Irving     27
# 22                                      Matt Bonner     27
# 23                                 Chauncey Billups     27
# 24                                       Tim Duncan     27
# 25                                     Derrick Rose     27
# 26                                  Jamaal Magloire     26
# 27                                      Joakim Noah     26
# 28    James Michael McAdoo / James McAdoo (Michael)     26
# 29                                 Shaun Livingston     26
# ...                                             ...    ...
# 1843               Ron Grandison / Ronnie Grandison      1
# 1844                                     Josh Moore      1
# 1845                                    Romain Sato      1
# 1846                     Roko-Leni Ukic / Roko Ukic      1
# 1847                                 Charles Oakley      1
# 1848                                 Justin Dentmon      1
# 1849                                  Chris Gatling      1
# 1850                                       Joe Wolf      1
# 1851                        Shai Gilgeous-Alexander      1
# 1852                                       Sam Mack      1
# 1853                                   Jeff Sanders      1
# 1854                                 Chris Robinson      1
# 1855                                  Chris Richard      1
# 1856                                    Chris Owens      1
# 1857                                   Semi Ojeleye      1
# 1858                                Sean Kilpatrick      1
# 1859                                    Sean Colson      1
# 1860                                     Sean Banks      1
# 1861                                  Scotty Hopson      1
# 1862                                  Jim McIlvaine      1
# 1863                                Jimmer Fredette      1
# 1864                                   Chris Marcus      1
# 1865                                  Scott Burrell      1
# 1866                                   Scott Brooks      1
# 1867                                 Antawn Johnson      1
# 1868                                    Jiri Welsch      1
# 1869                                    Joe Crispin      1
# 1870                                     Joe Dumars      1
# 1871                                      Sam Young      1
# 1872                                   Jerian Grant      1
#
# [1873 rows x 2 columns]

# %%
# 우선 이름 나누고 다시 for 돌려서 nba_02['name']에 들어있으면 저장
import re
for i in range(nba_injury_sum.shape[0]):
    for namedata in re.split('[/()]',nba_injury_sum.loc[i,'name']):
        if namedata.strip() in list(nba_02['name']):
            print(namedata.strip())
            nba_injury_sum.loc[i,'name'] = namedata.strip()
# Out:
# Tony Parker
# Manu Ginobili
# Dwyane Wade
# Andrew Bogut
# Sean Marks
# Melvin Ely
# Travis Diener
# Brian Cardinal
# Eduardo Najera
# Matt Bonner
# Chauncey Billups
# Tim Duncan
# Shaun Livingston
# Mike Miller
# Brian Scalabrine
# Luol Deng
# Dorell Wright
# Keyon Dooling
# Zaza Pachulia
# Kevin Garnett
# Theo Ratliff
# Jerry Stackhouse
# Corey Maggette
# Marvin Williams
# Joel Przybilla
# Mo Williams
# Jose Calderon
# Grant Hill
# DeSagana Diop
# Eddy Curry
# Josh Howard
# Jeff Foster
# Richard Hamilton
# Amar'e Stoudemire
# Daniel Gibson
# Tracy McGrady
# Shaquille O'Neal
# Stephen Jackson
# Andrei Kirilenko
# Zach Randolph
# Adonal Foyle
# Dirk Nowitzki
# Malik Allen
# Kobe Bryant
# David Lee
# Stephen Graham
# T.J. Ford
# David West
# Ronald Dupree
# Al Harrington
# Quentin Richardson
# Al Jefferson
# Leandro Barbosa
# Mehmet Okur
# Hedo Turkoglu
# Metta World Peace
# Jon Leuer
# Darko Milicic
# Caron Butler
# Elton Brand
# James Posey
# Jason Collins
# Jason Williams
# Chris Quinn
# Kevin Martin
# Zydrunas Ilgauskas
# Aaron Gray
# Ray Allen
# Tiago Splitter
# Ronny Turiaf
# Ronnie Price
# Yaroslav Korolev
# Primoz Brezec
# Paul Pierce
# Steve Francis
# Sean May
# Metta World Peace
# Nick Collison
# Nazr Mohammed
# Tony Battie
# Martell Webster
# Willie Green
# Vince Carter
# Allen Iverson
# Evan Turner
# Charlie Bell
# Boris Diaw
# Kris Humphries
# Anthony Parker
# Jared Jeffries
# James Jones
# Juwan Howard
# Yao Ming
# Luke Walton
# Royal Ivey
# Greg Oden
# Brad Miller
# Earl Barron
# Shawn Marion
# Jason Kidd
# Michael Redd
# Coby Karl
# Peja Stojakovic
# Kevin Ollie
# Paul Davis
# Darius Songaila
# Roy Hibbert
# Raja Bell
# Matt Barnes
# Luke Ridnour
# Julius Hodge
# Antonio McDyess
# Anthony Carter
# Larry Sanders
# Steve Blake
# Shane Battier
# Aaron Brooks
# DeShawn Stevenson
# Darren Collison
# Pops Mensah-Bonsu
# Richard Jefferson
# Adam Morrison
# Jason Richardson
# Jason Terry
# Marcin Gortat
# Sasha Kaun
# Jason Maxiell
# Antawn Jamison
# Rasheed Wallace
# Earl Watson
# Laron Profit
# Landry Fields
# Carlos Boozer
# Kevin Seraphin
# Derek Fisher
# Channing Frye
# Kelenna Azubuike
# Chris Duhon
# Ryan Gomes
# Stephon Marbury
# Gary Neal
# Corey Brewer
# Trevor Booker
# Fabricio Oberto
# Antoine Walker
# Mirza Teletovic
# Brandon Roy
# Bostjan Nachbar
# Steve Nash
# Jarron Collins
# Tayshaun Prince
# Mario West
# Trajan Langdon
# Rasho Nesterovic
# Robert Traylor
# Vladimir Stepania
# Robbie Hummel
# Nolan Smith
# Andres Nocioni
# Dan Dickau
# Luke Jackson
# Dee Brown
# Dee Brown
# Greg Ostertag
# Ime Udoka
# Chuck Hayes
# Kendall Marshall
# Rob Kurz
# Raul Lopez
# Kosta Perovic
# Travis Hansen
# Pablo Prigioni
# Jiri Welsch

# %%
nba_injury_sum.head()
# Out:
#             name  Notes
# 0    Tony Parker     50
# 1  Manu Ginobili     44
# 2    Dwyane Wade     43
# 3     C.J. Miles     37
# 4   Andrew Bogut     36

# %%
# Notes에서 NaN값을 발견, dropna함, 최종분석파일
nba_injury_merge = pd.merge(nba_02,nba_injury_sum,on='name',how='left').sort_values('Notes',ascending=False).reset_index(drop=True)
nba_injury_merge.dropna(inplace=True)
nba_injury_merge.sort_values('season',ascending=False).reset_index(drop=True)
# Out:
#                   name  age  season  Notes
# 0         Vince Carter   43      22   12.0
# 1        Dirk Nowitzki   40      21   18.0
# 2        Kevin Garnett   40      20   23.0
# 3          Kobe Bryant   37      20   17.0
# 4          Paul Pierce   39      19   13.0
# 5          Jason Terry   42      19    8.0
# 6           Tim Duncan   40      19   27.0
# 7          Tony Parker   37      18   50.0
# 8           Steve Nash   41      18    5.0
# 9         Derek Fisher   39      18    6.0
# 10           Ray Allen   41      18   14.0
# 11       Nazr Mohammed   39      18   13.0
# 12   Metta World Peace   37      17   15.0
# 13        Juwan Howard   40      17   11.0
# 14         Elton Brand   37      17   14.0
# 15   Metta World Peace   37      17   13.0
# 16       Zach Randolph   38      17   18.0
# 17   Richard Jefferson   38      17    8.0
# 18          Jason Kidd   40      17   10.0
# 19    Jerry Stackhouse   38      17   23.0
# 20    Chauncey Billups   37      17   27.0
# 21         Mike Miller   38      17   25.0
# 22       Zaza Pachulia   35      16   23.0
# 23        Shawn Marion   37      16   10.0
# 24         Dwyane Wade   37      16   43.0
# 25       Manu Ginobili   41      16   44.0
# 26      Antawn Jamison   38      16    7.0
# 27          Grant Hill   40      16   20.0
# 28       Al Harrington   35      16   15.0
# 29       Tracy McGrady   34      15   19.0
# ..                 ...  ...     ...    ...
# 143    Fabricio Oberto   35       6    6.0
# 144        Chris Quinn   30       6   14.0
# 145     Stephen Graham   33       6   17.0
# 146      Larry Sanders   26       6    9.0
# 147      Ronald Dupree   33       6   15.0
# 148      Travis Diener   32       5   34.0
# 149   Kelenna Azubuike   31       5    6.0
# 150      Landry Fields   28       5    7.0
# 151           Sean May   31       4   13.0
# 152         Mario West   31       4    4.0
# 153        Jiri Welsch   38       4    1.0
# 154       Laron Profit   35       4    7.0
# 155   Kendall Marshall   26       4    2.0
# 156       Luke Jackson   31       4    3.0
# 157         Paul Davis   31       4   10.0
# 158     Pablo Prigioni   39       4    1.0
# 159  Pops Mensah-Bonsu   32       4    8.0
# 160          Greg Oden   28       3   11.0
# 161      Adam Morrison   29       3    8.0
# 162     Trajan Langdon   35       3    4.0
# 163        Nolan Smith   27       2    3.0
# 164      Robbie Hummel   28       2    3.0
# 165         Raul Lopez   36       2    2.0
# 166       Julius Hodge   31       2    9.0
# 167          Coby Karl   32       2   10.0
# 168   Yaroslav Korolev   29       2   14.0
# 169         Sasha Kaun   31       1    7.0
# 170           Rob Kurz   28       1    2.0
# 171      Kosta Perovic   30       1    2.0
# 172      Travis Hansen   33       1    1.0
#
# [173 rows x 4 columns]

# %%
def corr(data,text):
    corr = data.corr(method='pearson')
    display(corr)
    style.use('ggplot')
    plt.title(text)
    sns.heatmap(data = corr, annot=True, fmt = '.2f', linewidths=.5, cmap='Blues')

# %%
corr(nba_injury_merge,'상관관계')
# Out:
#              age    season     Notes
# age     1.000000  0.717622  0.247140
# season  0.717622  1.000000  0.436517
# Notes   0.247140  0.436517  1.000000

# %%
# 부상  횟수 상위 10명
top_10 = nba_injury_merge.sort_values('Notes',ascending=False).head(10).reset_index(drop=True)
corr(top_10,'상관관계')
# Out:
#              age    season     Notes
# age     1.000000  0.654596  0.444425
# season  0.654596  1.000000  0.637982
# Notes   0.444425  0.637982  1.000000

# %%
top_15 = nba_injury_merge.sort_values('Notes',ascending=False).head(15).reset_index(drop=True)
corr(top_15,'상관관계')
# Out:
#              age    season     Notes
# age     1.000000  0.674477  0.274346
# season  0.674477  1.000000  0.154684
# Notes   0.274346  0.154684  1.000000

# %%
top_15
# Out:
#                 name  age  season  Notes
# 0        Tony Parker   37      18   50.0
# 1      Manu Ginobili   41      16   44.0
# 2        Dwyane Wade   37      16   43.0
# 3       Andrew Bogut   36      14   36.0
# 4         Sean Marks   36      11   35.0
# 5         Melvin Ely   38       9   35.0
# 6      Travis Diener   32       5   34.0
# 7     Brian Cardinal   36      12   30.0
# 8     Eduardo Najera   36      12   28.0
# 9        Matt Bonner   36      12   27.0
# 10        Tim Duncan   40      19   27.0
# 11  Chauncey Billups   37      17   27.0
# 12  Shaun Livingston   34      14   26.0
# 13       Mike Miller   38      17   25.0
# 14  Brian Scalabrine   34      11   25.0

# %%
nba_injury_merge.describe()
# Out:
#               age      season       Notes
# count  173.000000  173.000000  173.000000
# mean    34.658960   11.011561   13.121387
# std      3.345318    4.755643    8.608558
# min     26.000000    1.000000    1.000000
# 25%     33.000000    8.000000    7.000000
# 50%     35.000000   12.000000   12.000000
# 75%     37.000000   14.000000   17.000000
# max     43.000000   22.000000   50.000000

# %% [markdown]
# # 의사결정나무 예측

# %%
from sklearn.datasets import load_iris
from sklearn.tree     import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, KFold, cross_val_score, cross_validate,  GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

import sklearn
print(sklearn.__version__)

# %%
nba_label = nba_injury_merge['age']
nba_data = nba_injury_merge.loc[:,['season','Notes']]

X_train, X_test, y_train, y_test =train_test_split(nba_data, nba_label, test_size = 0.2,  random_state=5)

# %%
print('train data\n' ,X_train )
print('train label\n' ,y_train )
print('*'*50)
print('test data\n' ,X_test )
print('test label\n' ,y_test )
# Out:
# train data
#       season  Notes
# 47       15   16.0
# 63        7   14.0
# 98        8   10.0
# 20       15   23.0
# 21       20   23.0
# 88        9   12.0
# 100      13   10.0
# 72        8   13.0
# 112      10    9.0
# 29       16   20.0
# 128       1    7.0
# 68       14   14.0
# 59       13   14.0
# 35       14   19.0
# 55       14   15.0
# 86       11   12.0
# 67       10   14.0
# 140       8    6.0
# 153      12    4.0
# 123      17    8.0
# 37       15   19.0
# 125      16    7.0
# 0        18   50.0
# 5         9   35.0
# 11       19   27.0
# 109       2    9.0
# 172       1    1.0
# 49       13   15.0
# 134      13    6.0
# 104      13   10.0
# ..      ...    ...
# 18       17   23.0
# 167      10    2.0
# 155       8    3.0
# 10       12   27.0
# 32       13   19.0
# 110      14    9.0
# 83       14   12.0
# 61        7   14.0
# 131       5    7.0
# 25       13   21.0
# 141       8    6.0
# 161       8    3.0
# 6         5   34.0
# 7        12   30.0
# 101       8   10.0
# 105      12   10.0
# 144       6    5.0
# 16       13   24.0
# 26       14   21.0
# 40       10   18.0
# 118      19    8.0
# 162       8    3.0
# 71       10   14.0
# 22       13   22.0
# 75        9   13.0
# 148      10    5.0
# 137       7    6.0
# 156       2    3.0
# 15       15   25.0
# 99       16   10.0
#
# [138 rows x 2 columns]
# train label
#  47     38
# 63     33
# 98     37
# 20     38
# 21     40
# 88     37
# 100    34
# 72     37
# 112    35
# 29     40
# 128    31
# 68     37
# 59     36
# 35     33
# 55     37
# 86     31
# 67     33
# 140    33
# 153    35
# 123    38
# 37     34
# 125    38
# 0      37
# 5      38
# 11     40
# 109    31
# 172    33
# 49     34
# 134    36
# 104    37
#        ..
# 18     38
# 167    38
# 155    37
# 10     36
# 32     35
# 110    37
# 83     36
# 61     30
# 131    28
# 25     35
# 141    32
# 161    31
# 6      32
# 7      36
# 101    36
# 105    37
# 144    28
# 16     34
# 26     38
# 40     36
# 118    42
# 162    31
# 71     29
# 22     34
# 75     33
# 148    32
# 137    34
# 156    27
# 15     34
# 99     37
# Name: age, Length: 138, dtype: int64
# **************************************************
# test data
#       season  Notes
# 64        2   14.0
# 92       14   11.0
# 121      12    8.0
# 168      11    2.0
# 102       4   10.0
# 45        6   17.0
# 34       13   19.0
# 111      14    9.0
# 169       1    2.0
# 62       18   14.0
# 13       17   25.0
# 77       14   13.0
# 160       7    3.0
# 97       17   10.0
# 46        8   17.0
# 119      13    8.0
# 150      12    5.0
# 28       12   20.0
# 170       4    1.0
# 107       9   10.0
# 103      12   10.0
# 147      18    5.0
# 129      10    7.0
# 80       10   13.0
# 44       12   17.0
# 89        7   12.0
# 149       6    5.0
# 65        8   14.0
# 165       2    2.0
# 96       10   11.0
# 51       10   15.0
# 87       22   12.0
# 12       14   26.0
# 90       10   12.0
# 1        16   44.0
# test label
#  64     29
# 92     36
# 121    36
# 168    33
# 102    31
# 45     33
# 34     34
# 111    37
# 169    28
# 62     41
# 13     38
# 77     37
# 160    34
# 97     40
# 46     28
# 119    34
# 150    35
# 28     32
# 170    39
# 107    31
# 103    34
# 147    41
# 129    34
# 80     30
# 44     34
# 89     37
# 149    33
# 65     31
# 165    36
# 96     33
# 51     33
# 87     43
# 12     34
# 90     32
# 1      41
# Name: age, dtype: int64

# %%
nba_dtc = DecisionTreeClassifier(random_state=5)
nba_dtc.fit(X_train, y_train)

nba_dtc_entropy = DecisionTreeClassifier(random_state=5, criterion='entropy')
nba_dtc_entropy.fit(X_train, y_train)

predition_gini = nba_dtc.predict(X_test)
# print(' y_test\n', y_test)
# print(' prediction\n', predition_gini)

predition_entropy = nba_dtc_entropy.predict(X_test)
# print(' y_test\n', y_test)
# print(' prediction\n', predition_entropy)

from sklearn.metrics import accuracy_score
print('예측 정확도 : %.2f' % accuracy_score(y_test, predition_gini))
print('예측 정확도 : %.2f' % accuracy_score(y_test, predition_entropy))
# Out:
# 예측 정확도 : 0.26
# 예측 정확도 : 0.23

# %%
nba_gini_pred = pd.DataFrame({
    '원래나이' : y_test,
    '예측나이': predition_gini
})
nba_gini_pred
# Out:
#      원래나이  예측나이
# 171    38    39
# 17     34    34
# 127    38    38
# 21     40    40
# 56     30    30
# 43     37    41
# 130    35    32
# 53     37    38
# 149    33    28
# 119    34    35
# 46     28    33
# 102    31    32
# 126    30    34
# 26     38    34
# 39     38    38
# 114    38    35
# 63     33    30
# 40     36    33
# 104    37    34
# 28     32    35
# 167    38    35
# 54     33    30
# 117    31    34
# 25     35    34
# 51     33    33
# 42     40    43
# 77     37    37
# 122    29    31
# 148    32    31
# 23     34    38
# 71     29    33
# 1      41    37
# 153    35    35
# 135    40    36
# 161    31    31

# %%
kfold = KFold(n_splits=5)
cv_accuracy = []
print('nba_data', nba_data.shape[0])

nba_label_arr = np.array(nba_label.tolist())
# display(nba_label_arr)
nba_data_arr = np.array([[nba_data.get_value(i,'season'),nba_data.get_value(i,'Notes')] for i in nba_data.index])
# display(nba_data_arr)
# Out:
# nba_data 173
# array([37, 41, 37, 36, 36, 38, 32, 36, 36, 37, 36, 40, 34, 38, 34, 34, 34,
#        34, 38, 35, 38, 40, 34, 34, 34, 35, 38, 36, 32, 40, 30, 37, 35, 39,
#        34, 33, 37, 34, 29, 38, 36, 35, 40, 37, 34, 33, 28, 38, 36, 34, 35,
#        33, 34, 37, 33, 37, 30, 35, 36, 36, 33, 30, 41, 33, 29, 31, 35, 33,
#        37, 35, 37, 29, 37, 31, 35, 33, 39, 37, 39, 37, 30, 37, 36, 36, 38,
#        34, 31, 43, 37, 37, 32, 32, 36, 28, 30, 40, 33, 40, 37, 37, 34, 36,
#        31, 34, 37, 37, 32, 31, 26, 31, 37, 37, 35, 35, 38, 35, 37, 31, 42,
#        34, 32, 36, 29, 38, 35, 38, 30, 38, 31, 34, 35, 28, 36, 35, 36, 40,
#        34, 34, 31, 31, 33, 32, 35, 39, 28, 37, 37, 41, 32, 33, 35, 35, 31,
#        35, 28, 37, 27, 31, 32, 33, 34, 31, 31, 26, 30, 36, 35, 38, 33, 28,
#        39, 38, 33])
# array([[18., 50.],
#        [16., 44.],
#        [16., 43.],
#        [14., 36.],
#        [11., 35.],
#        [ 9., 35.],
#        [ 5., 34.],
#        [12., 30.],
#        [12., 28.],
#        [17., 27.],
#        [12., 27.],
#        [19., 27.],
#        [14., 26.],
#        [17., 25.],
#        [11., 25.],
#        [15., 25.],
#        [13., 24.],
#        [11., 24.],
#        [17., 23.],
#        [16., 23.],
#        [15., 23.],
#        [20., 23.],
#        [13., 22.],
#        [15., 22.],
#        [14., 22.],
#        [13., 21.],
#        [14., 21.],
#        [10., 20.],
#        [12., 20.],
#        [16., 20.],
#        [11., 20.],
#        [14., 19.],
#        [13., 19.],
#        [15., 19.],
#        [13., 19.],
#        [14., 19.],
#        [14., 19.],
#        [15., 19.],
#        [ 7., 19.],
#        [17., 18.],
#        [10., 18.],
#        [12., 18.],
#        [21., 18.],
#        [20., 17.],
#        [12., 17.],
#        [ 6., 17.],
#        [ 8., 17.],
#        [15., 16.],
#        [15., 15.],
#        [13., 15.],
#        [16., 15.],
#        [10., 15.],
#        [14., 15.],
#        [17., 15.],
#        [ 6., 15.],
#        [14., 15.],
#        [ 6., 14.],
#        [12., 14.],
#        [12., 14.],
#        [13., 14.],
#        [12., 14.],
#        [ 7., 14.],
#        [18., 14.],
#        [ 7., 14.],
#        [ 2., 14.],
#        [ 8., 14.],
#        [13., 14.],
#        [10., 14.],
#        [14., 14.],
#        [12., 14.],
#        [17., 14.],
#        [10., 14.],
#        [ 8., 13.],
#        [ 4., 13.],
#        [12., 13.],
#        [ 9., 13.],
#        [19., 13.],
#        [14., 13.],
#        [18., 13.],
#        [14., 13.],
#        [10., 13.],
#        [17., 13.],
#        [14., 12.],
#        [14., 12.],
#        [14., 12.],
#        [13., 12.],
#        [11., 12.],
#        [22., 12.],
#        [ 9., 12.],
#        [ 7., 12.],
#        [10., 12.],
#        [10., 11.],
#        [14., 11.],
#        [ 3., 11.],
#        [ 8., 11.],
#        [17., 11.],
#        [10., 11.],
#        [17., 10.],
#        [ 8., 10.],
#        [16., 10.],
#        [13., 10.],
#        [ 8., 10.],
#        [ 4., 10.],
#        [12., 10.],
#        [13., 10.],
#        [12., 10.],
#        [ 2., 10.],
#        [ 9., 10.],
#        [ 6.,  9.],
#        [ 2.,  9.],
#        [14.,  9.],
#        [14.,  9.],
#        [10.,  9.],
#        [13.,  9.],
#        [13.,  9.],
#        [12.,  9.],
#        [13.,  9.],
#        [10.,  8.],
#        [19.,  8.],
#        [13.,  8.],
#        [ 4.,  8.],
#        [12.,  8.],
#        [ 3.,  8.],
#        [17.,  8.],
#        [13.,  8.],
#        [16.,  7.],
#        [ 7.,  7.],
#        [15.,  7.],
#        [ 1.,  7.],
#        [10.,  7.],
#        [ 4.,  7.],
#        [ 5.,  7.],
#        [13.,  7.],
#        [13.,  7.],
#        [13.,  6.],
#        [13.,  6.],
#        [12.,  6.],
#        [ 7.,  6.],
#        [ 5.,  6.],
#        [ 9.,  6.],
#        [ 8.,  6.],
#        [ 8.,  6.],
#        [ 6.,  6.],
#        [18.,  6.],
#        [ 6.,  5.],
#        [14.,  5.],
#        [ 6.,  5.],
#        [18.,  5.],
#        [10.,  5.],
#        [ 6.,  5.],
#        [12.,  5.],
#        [ 3.,  4.],
#        [ 4.,  4.],
#        [12.,  4.],
#        [ 2.,  3.],
#        [ 8.,  3.],
#        [ 2.,  3.],
#        [ 4.,  3.],
#        [ 6.,  3.],
#        [ 6.,  3.],
#        [ 7.,  3.],
#        [ 8.,  3.],
#        [ 8.,  3.],
#        [ 4.,  2.],
#        [ 1.,  2.],
#        [ 2.,  2.],
#        [ 7.,  2.],
#        [10.,  2.],
#        [11.,  2.],
#        [ 1.,  2.],
#        [ 4.,  1.],
#        [ 4.,  1.],
#        [ 1.,  1.]])

# %%
n_iter = 0
for train_idx, test_idx in kfold.split(nba_data):
#     print(train_idx, test_idx)
    X_train, X_test = nba_data_arr[train_idx],nba_data_arr[test_idx]
#     print('X_train\n',X_train)
#     print('X_test\n', X_test)
    y_train, y_test = nba_label_arr[train_idx], nba_label_arr[test_idx]
#     print('y_train', y_train)
#     print('y_test', y_test)
    # 학습을 진행하겠다면?
    nba_dtc.fit(X_train, y_train)
    # 예측
    fold_pred = nba_dtc.predict(X_test)
    
    # 정확도 측정
    n_iter += 1
    accuracy = np.round(accuracy_score(y_test, fold_pred),4)
    print('\n{}교차검증 정확도 :  {}, 학습 데이터 크기 : {}, 검증 데이터 크기 : {}'.format(n_iter, accuracy,X_train.shape[0], X_test.shape[0]))
    cv_accuracy.append(accuracy)
print('\n\n')
print('\n 평균 검증 정확도 : ', np.mean(cv_accuracy))
# Out:
# 1교차검증 정확도 :  0.1143, 학습 데이터 크기 : 138, 검증 데이터 크기 : 35
#
# 2교차검증 정확도 :  0.2571, 학습 데이터 크기 : 138, 검증 데이터 크기 : 35
#
# 3교차검증 정확도 :  0.1714, 학습 데이터 크기 : 138, 검증 데이터 크기 : 35
#
# 4교차검증 정확도 :  0.0882, 학습 데이터 크기 : 139, 검증 데이터 크기 : 34
#
# 5교차검증 정확도 :  0.0882, 학습 데이터 크기 : 139, 검증 데이터 크기 : 34
#
#
#
#
#  평균 검증 정확도 :  0.14384000000000002

# %%
# 이거면 kfold안해도 된다. 근데 이거는 분류에 적용되고 회귀는 안 된다.
scoring = cross_val_score(nba_dtc,nba_data_arr,nba_label_arr,scoring='accuracy',cv=3 )
print('교차 검증별 정확도 :',scoring)
print('평균 검증 정확도 :',np.mean(scoring))
# Out:
# 교차 검증별 정확도 : [0.22413793 0.24137931 0.12280702]
# 평균 검증 정확도 : 0.19610808630772336

# %%
scoring2 = cross_validate(nba_dtc,nba_data_arr,nba_label_arr,scoring='accuracy',cv=10)
print('교차 검증 정보 :',scoring2)
print('교차 검증별 정확도 :',scoring2['test_score'])
print('교차 검증 시간 :',scoring2['fit_time'])
print('평균 검증 정확도 :',np.mean(scoring2['test_score']))
# Out:
# 교차 검증 정보 : {'fit_time': array([0.00099874, 0.00099587, 0.        , 0.00199699, 0.00199533,
#        0.0009973 , 0.0010004 , 0.00199723, 0.        , 0.00099063]), 'score_time': array([0.0009973 , 0.        , 0.00099754, 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.0010047 , 0.        ]), 'test_score': array([0.22222222, 0.38888889, 0.33333333, 0.17647059, 0.23529412,
#        0.11764706, 0.05882353, 0.05882353, 0.29411765, 0.11764706])}
# 교차 검증별 정확도 : [0.22222222 0.38888889 0.33333333 0.17647059 0.23529412 0.11764706
#  0.05882353 0.05882353 0.29411765 0.11764706]
# 교차 검증 시간 : [0.00099874 0.00099587 0.         0.00199699 0.00199533 0.0009973
#  0.0010004  0.00199723 0.         0.00099063]
# 평균 검증 정확도 : 0.20032679738562092

# %%
gscv_tree = DecisionTreeClassifier(random_state=20)
params = {'criterion' : ['gini', 'entropy'], 
          'splitter' : ['random','best'], 
          'max_depth' : [1,2,3], 
          'min_samples_split' : [2,3]}

grid_gscv_tree = GridSearchCV(gscv_tree, param_grid = params,cv=3,refit=True )

grid_gscv_tree.fit(X_train, y_train)
grid_gscv_tree.cv_results_
score_df = pd.DataFrame(grid_gscv_tree.cv_results_)
# score_df[['params', 'mean_test_score', 'rank_test_score','split0_test_score','split1_test_score','split2_test_score']]

# %%
print('최적의 파라미터 : ', grid_gscv_tree.best_params_)
print('높은 정확도 : ', grid_gscv_tree.best_score_)
# Out:
# 최적의 파라미터 :  {'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 높은 정확도 :  0.2086031452358927

# %%
estimator = grid_gscv_tree.best_estimator_
prediction = estimator.predict(X_test)
print('answer : ', y_test)
print('guess : ', prediction)
print('테스트 세트의 정확도 : ', accuracy_score(y_test,prediction))
# Out:
# answer :  [31 33 32 35 39 28 37 37 41 32 33 35 35 31 35 28 37 27 31 32 33 34 31 31
#  26 30 36 35 38 33 28 39 38 33]
# guess :  [36 30 30 30 39 30 37 30 39 36 30 36 31 31 36 31 30 31 31 30 30 30 30 30
#  31 31 31 30 36 36 31 31 31 31]
# 테스트 세트의 정확도 :  0.11764705882352941

# %%
# 표준화
sc = StandardScaler()
sc.fit(X_train)

X_train_std = sc.transform(X_train) #트레이닝 데이터의 표준화
X_test_std = sc.transform(X_test) # 테스트 데이터의 표준화

criterion_dtc = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)
# 표준화 작업 했으면 표준화 된 데이터를 넣는다.
criterion_dtc.fit(X_train_std, y_train)

y_pred = criterion_dtc.predict(X_test_std)
print('총 테스트 개수 : %d, 오류의 개수 : %d' % ( len(y_test), (y_test != y_pred).sum()) )
print('정확도 : %.2f' % accuracy_score(y_test, y_pred))
# Out:
# 총 테스트 개수 : 34, 오류의 개수 : 25
# 정확도 : 0.26

# %%
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import platform

from matplotlib import font_manager, rc
# plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~') 
    
    
import seaborn as sns

import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False


def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):

    # 마커와 컬러맵을 설정합니다.
    markers = ('s', 'x', 'o', '^', 'v',
              's', 'x', 'o', '^', 'v',
              's', 'x', 'o', '^', 'v',
              's', 'x', 'o')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan',
             'red', 'blue', 'lightgreen', 'gray', 'cyan',
             'red', 'blue', 'lightgreen', 'gray', 'cyan',
             'red', 'blue', 'lightgreen')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # 결정 경계를 그립니다.
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.8, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=cl, 
                    edgecolor='black')

    # 테스트 샘플을 부각하여 그립니다.
    if test_idx:
        X_test, y_test = X[test_idx, :], y[test_idx]

        plt.scatter(X_test[:, 0],
                    X_test[:, 1],
                    facecolors='none',
                    edgecolor='black',
                    alpha=1.0,
                    linewidth=1,
                    marker='o',
                    s=100, 
                    label='test set')

# %%
# 불순도 검사
x_combind_std = np.vstack((X_train_std, X_test_std))
# print(combind_std)
y_combind = np.hstack((y_train, y_test))
# print(y_combind)
plot_decision_regions(X=x_combind_std,y=y_combind,classifier=criterion_dtc,test_idx=range(122,172))

# %%
import io
import pydot
from IPython.core.display import Image
from sklearn.tree import export_graphviz

def draw_decision_tree(model):
    dot_buf = io.StringIO()
    export_graphviz(model, out_file=dot_buf, feature_names=['season','Notes'])
    graph = pydot.graph_from_dot_data(dot_buf.getvalue())[0]
    image = graph.create_png()
    return Image(image)

# %%
# !pip install pydot
# Out:
# Collecting pydot
#   Downloading pydot-1.4.1-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\gh\anaconda3\lib\site-packages (from pydot) (2.2.0)
# Installing collected packages: pydot
# Successfully installed pydot-1.4.1

# %%
draw_decision_tree(criterion_dtc)

# %% [markdown]
# # 부상내역 크롤링

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.error   import HTTPError
from urllib.error   import URLError

import pandas as pd

# %%
from selenium import webdriver
import time
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
def craw(start,end):
    page_list = [ i for i in range(start,end,25)]
    Date = []
    Team = []
    Acquired = []
    Relinquished = []
    Notes = []
    for page in page_list:
        driver.get('http://www.prosportstransactions.com/basketball/Search/SearchResults.php?Player=&Team=&BeginDate=1998-01-01&EndDate=2020-12-31&ILChkBx=yes&Submit=Search&start='+str(page))
        page = driver.find_elements_by_css_selector('.datatable')
        if len(page) != 0:
            for i in page[0].find_elements_by_tag_name('tbody'):
                k = i.find_elements_by_tag_name('tr')
                for data in k:
                    ll = data.find_elements_by_tag_name('td')
                    Date.append(ll[0].text)
                    Team.append(ll[1].text)
                    Acquired.append(ll[2].text)
                    Relinquished.append(ll[3].text)
                    Notes.append(ll[4].text)
    return   Date,Team, Acquired,Relinquished, Notes

# %%
Date,Team, Acquired,Relinquished, Notes = craw(0,5001)
Date1,Team1, Acquired1,Relinquished1, Notes1 = craw(5001,10001)
Date2,Team2, Acquired2,Relinquished2, Notes2 = craw(10001,15001)
Date3,Team3, Acquired3,Relinquished3, Notes3 = craw(15000,20001)
Date4,Team4, Acquired4,Relinquished4, Notes4 = craw(20001,25001)
Date5,Team5, Acquired5,Relinquished5, Notes5 = craw(25001,28526)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-efa7c247e146> in <module>()
#       2 # Date1,Team1, Acquired1,Relinquished1, Notes1 = craw(5001,10001)
#       3 # Date2,Team2, Acquired2,Relinquished2, Notes2 = craw(10001,15001)
# ----> 4 Date3,Team3, Acquired3,Relinquished3, Notes3 = craw(15000,20001)
#       5 Date3,Team3, Acquired3,Relinquished3, Notes3 = craw(20001,25001)
#       6 Date4,Team4, Acquired4,Relinquished4, Notes4 = craw(25000,28526)
#
# <ipython-input-38-45f5ff3dbb2f> in craw(start, end)
#      16                 Date.append(ll[0].text)
#      17                 Team.append(ll[1].text)
# ---> 18                 Acquired.append(ll[2].text)
#      19                 Relinquished.append(ll[3].text)
#      20                 Notes.append(ll[4].text)
#
# IndexError: list index out of range

# %%
df1 = pd.DataFrame({
    'Date':Date,
    'Team' : Team,
    'Acquired' : Acquired,
    'Relinquished' : Relinquished,
    'Notes' : Notes    
                   })

# %%
df2 = pd.DataFrame({
    'Date':Date1,
    'Team' : Team1,
    'Acquired' : Acquired1,
    'Relinquished' : Relinquished1,
    'Notes' : Notes1    
                   })

# %%
df3 = pd.DataFrame({
    'Date':Date2,
    'Team' : Team2,
    'Acquired' : Acquired2,
    'Relinquished' : Relinquished2,
    'Notes' : Notes2    
                   })

# %%
df4 = pd.DataFrame({
    'Date':Date3,
    'Team' : Team3,
    'Acquired' : Acquired3,
    'Relinquished' : Relinquished3,
    'Notes' : Notes3   
                   })

# %%
df5 = pd.DataFrame({
    'Date':Date4,
    'Team' : Team4,
    'Acquired' : Acquired4,
    'Relinquished' : Relinquished4,
    'Notes' : Notes4  
                   })

# %%
df6 = pd.DataFrame({
    'Date':Date5,
    'Team' : Team5,
    'Acquired' : Acquired5,
    'Relinquished' : Relinquished5,
    'Notes' : Notes5 
                   })

# %%
df1.to_csv('df1.csv',mode='w',index=False)
df2.to_csv('df2.csv',mode='w',index=False)
df3.to_csv('df3.csv',mode='w',index=False)

# %%
df4.to_csv('df4.csv',mode='w',index=False)
df5.to_csv('df5.csv',mode='w',index=False)

# %%
df6.to_csv('df6.csv',mode='w',index=False)

# %%
nba_injury_1998 = pd.concat([df1,df2,df3,df4,df5,df6])
drop_index = list(nba_injury_1998[nba_injury_1998['Date']==' Date'].index)
nba_injury_1998 = nba_injury_1998.drop(drop_index).reset_index(drop=True)
none_Relinquished = list(nba_injury_1998[nba_injury_1998['Relinquished'] ==''].index)
nba_injury_1998 = nba_injury_1998.drop(none_Relinquished).reset_index(drop=True)
nba_injury_1998 = nba_injury_1998.drop(['Acquired'],axis=1)  
nba_injury_1998.to_csv('nba_injury_1998.csv',mode='w',index=False)

# %%
for i in range(nba_injury_1998.shape[0]):
    if nba_injury_1998.loc[i,'Relinquished'] != '':
        nba_injury_1998.loc[i,'Relinquished'] = nba_injury_1998.loc[i,'Relinquished'].split('•')[1].strip()
        nba_injury_1998.loc[i,'Date'] = nba_injury_1998.loc[i,'Date'].strip()
        nba_injury_1998.loc[i,'Team'] = nba_injury_1998.loc[i,'Team'].strip()
        nba_injury_1998.loc[i,'Notes'] = nba_injury_1998.loc[i,'Notes'].strip()
    if nba_injury_1998.loc[i,'Relinquished'] =='':
        nba_injury_1998.loc[i,'Relinquished'] = nba_injury_1998.loc[i,'Relinquished']
        nba_injury_1998.loc[i,'Date'] = nba_injury_1998.loc[i,'Date'].strip()
        nba_injury_1998.loc[i,'Team'] = nba_injury_1998.loc[i,'Team'].strip()
        nba_injury_1998.loc[i,'Notes'] = nba_injury_1998.loc[i,'Notes'].strip()

# %%
for i in range(nba_injury_1998.shape[0]):
    data = nba_injury_1998.loc[i,'Notes'].split('with')
    print(data)
    if data[0] in  ['placed on IL ','placed on IR ']:
        nba_injury_1998.loc[i,'Notes2'] = data[1].strip()
    else:
        nba_injury_1998.loc[i,'Notes2'] = nba_injury_1998.loc[i,'Notes']
# Out:
# ['placed on IL ', ' flu']
# ['placed on IR ', ' left wrist tendinitis']
# ['placed on IL ', ' flu / sore knees (P)']
# ['placed on IL ', ' herniated disc in neck']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' patella tendinitis']
# ['placed on IL ', ' flu']
# ['placed on IR ', ' left leg stress reaction']
# ['placed in IR ', ' small tear in right hamstring']
# ['placed on IR ', ' right ankle synovitis']
# ['placed on IL ', ' sprained right foot']
# ['placed on IL ', ' elbow synovitis']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sore right shoulder']
# ['placed on IL ', ' hyperextended left knee']
# ['placed on IR ', ' plantar fasciitis in right foot']
# ['placed on IL ', ' strained right shoulder']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IR ', ' pulled left groin']
# ['placed on IR ', ' fractured left clavicle (out 6-8 weeks)']
# ['hamstring injury (DNP)']
# ['sore lower back (DTD)']
# ['placed on IL ', ' sprained right big toe']
# ['placed on IL ', ' strained right groin']
# ['placed on IL ', ' flu']
# ['placed on IL ', ' strained right calf']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' broken right index finger']
# ['placed on IL ', ' surgery on left knee (out indefinitely)']
# ['placed on IL ', ' patella tendinitis']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' strained groin']
# ['placed on IR ', ' strained abdomen & pulled groin']
# ['placed on IL ', ' right ankle tendinitis']
# ['placed on IL ', ' strained right hamstring']
# ['placed on IL ', ' left knee patellar tendinitis']
# ['placed on IL ', ' separated left shoulder']
# ['placed on IL ', ' left knee inflammation']
# ['placed on IR ', ' torn ligaments in right thumb']
# ['placed on IL ', ' strained right calf']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' left Achilles tendinitis']
# ['placed on IL ', ' sprained MCL in right knee']
# ['left game ', ' bruised tailbone']
# ['placed on IL ', ' strained left groin']
# ['placed on IR ', ' ankle injury / torn cartilage in right knee (P)']
# ['placed on IL ', ' strained right calf']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' right knee surgery (out 2-3 weeks)']
# ['placed on IL ', ' right Achilles tendinitis']
# ['placed on IL ', ' sprained MCL in right knee']
# ['placed on IL ', ' strained lower back']
# ['placed on IR ', ' ligament damage in left thumb (out 2-4 weeks)']
# ['placed on IL ', ' fractured right foot']
# ['placed on IR ', ' torn left ACL (out for season)']
# ['placed on IR ', ' fractured right hand (out 4-6 weeks)']
# ['placed on IL ', ' sore left knee']
# ['placed on IR ', ' fractured right ring finger']
# ['placed on IL ', ' lower back pain']
# ['placed on IR ', ' fractured right thumb']
# ['placed on IR ', ' ankle surgery to remove bone spurs']
# ['placed on IL ', ' right knee inflammation']
# ['placed on IL ', ' broken bone in right foot']
# ['placed on IR ', ' surgery on foot (out 3 weeks)']
# ['placed on IR ', ' lateral pain in right knee']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' bruised right hip']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' left patella tendinitis']
# ['placed on IL ', ' bone spurs in right foot']
# ['placed on IL ', ' sore back']
# ['placed on IL ', ' bone bruise in right foot']
# ['placed on IR ', ' injured right hamstring']
# ['placed on IR ', ' partially torn left Achilles tendon']
# ['placed on IL ', ' strained abdominal muscle']
# ['placed on IL ', ' strained left hip flexor']
# ['placed on IR ', ' chronic patella tendinitis in right knee']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' strained right hip flexor']
# ['placed on IL ', ' hyperextended left knee / bone compression in the tibial plateau (P)']
# ['placed on IR ', ' torn lateral meniscus in left knee']
# ['placed on IL ', ' strained left calf muscle']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' strained lower back']
# ['strained right ankle (DNP)']
# ['placed on IL ', ' strained right hamstring']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' right knee patella tendinitis']
# ['placed on IL ', ' sprained left knee']
# ['placed on IR ', ' fractured left ankle']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' strained abdominal muscle']
# ['placed on IL ', ' right knee inflammation']
# ['sprained right ankle (DTD)']
# ['placed on IL ', ' lower back pain']
# ['placed on IR ', ' plantar fasciaitis of the right heel and an avulsion fracture of the right heel bone']
# ['placed on IR ', ' strained Achilles tendon']
# ['placed on IL ', ' strained left shoulder']
# ['placed on IR ', ' inflamed tendon in right foot']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' fractured rib']
# ['placed on IL ', ' bone bruise in left knee']
# ['placed on IL ', ' torn ACL in right knee (out for season)']
# ['placed on IL ', ' left Achilles tendinitis']
# ['placed on IR ', ' broken left foot']
# ['placed on IR ', ' subluxation of right shoulder']
# ['placed on IL ', ' strained left groin']
# ['placed on IL ', ' strained lower back']
# ['placed on IR ', ' broken right thumb (out for season)']
# ['placed on IR ', ' acute right patellar tendinitis']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' strained left groin']
# ['placed on IL ', ' strained abdominal muscle']
# ['placed on IL ', ' right knee inflammation']
# ['placed on IR ', ' aggravated left hamstring']
# ['placed on IL ', ' strained left hamstring']
# ['placed on IL ', ' sore left knee']
# ['placed on IL']
# ['placed on IL ', ' bruised left thigh']
# ['placed on IL ', ' sore left knee']
# ['placed on IR ', ' left leg stress fracture (out 2 months)']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' concussion']
# ['placed on IR ', ' stress fractures in both feet']
# ['placed on IL ', ' knee injury']
# ['placed on IL']
# ['placed on IL']
# ['placed on IL']
# ['placed on IR ', ' tendinitis in left foot']
# ['placed on IL']
# ['placed on IL']
# ['placed on IL ', ' surgery on left knee']
# ['placed on IL ', ' strained MCL in knee']
# ['placed on IL']
# ['placed on IL']
# ['placed on IL ', ' knee injury']
# ['placed on IL']
# ['placed on IL ', ' back injury']
# ['placed on IR ', ' ruptured right biceps tendon (out for season)']
# ['placed on IL ', ' strained lower back']
# ['placed on IL']
# ['placed on IR ', ' pulled groin']
# ['placed on IR ', ' sprained knee']
# ['placed on IL ', ' torn right Achilles tendon']
# ['placed on IL ', ' back spasms']
# ['placed on IL']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' surgery on right knee (out 4-6 weeks)']
# ['placed on IR ', ' torn right pectoral tendon in chest (out 6-8 weeks)']
# ['placed on IL']
# ['placed on IL ', ' bruised right foot']
# ['placed on IR ', ' stress fractures in both legs']
# ['placed on IR ', ' stress fracture in right heel']
# ['placed on IL ', ' bruised right foot']
# ['placed on IR ', ' broken left pinky finger']
# ['placed on IR ', ' deep thigh bruise (out 2 weeks)']
# ['placed on IL ', ' broken bone in left foot']
# ['placed on IL ', ' broken left ring finger']
# ['placed on IL ', ' left Achilles tendinitis']
# ['placed on IL ', ' left knee patella tendinitis']
# ['placed on IL ', ' surgery on left knee']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IR ', ' fractured navicular bone in left foot (out for season)']
# ['placed on IR ', ' sprained left quadricep / strained hip flexor (P)']
# ['placed on IL ', ' strained right groin']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' bruised left quadricep']
# ['placed on IL ', ' sore left knee']
# ['placed on IL']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' abdominal strain']
# ['placed on IL ', ' sprained right big toe']
# ['placed on IL ', ' shin splints']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' back spasms']
# ['placed on IR ', ' quadricep tendinitis in right knee']
# ['placed on IL ', ' left Achilles tendinitis']
# ['placed on IL ', ' strained lower back']
# ['placed on IR ', ' fractured right ankle']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' sore back']
# ['placed on IR ', ' plantar facitis in right foot']
# ['placed on IR ', ' chondromalacia patella left knee']
# ['placed on IL ', ' patellar tendinitis in right knee']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' lower back spasms']
# ['placed on IR ', ' chicken pox']
# ['placed on IL ', ' a sprained right knee']
# ['placed on IL ', ' sore left foot / plantar fasciatis in right foot']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' torn ACL in left knee (out for season)']
# ['placed on IL ', ' strained right hamstring']
# ['placed on IL ', ' fractured right wrist']
# ['placed on IL ', ' strained left quadricep']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' back spasms / strained lower back']
# ['placed on IL ', ' sore right knee']
# ['placed on IR ', ' strained tendon in right leg']
# ['placed on IL ', ' lower back spasms']
# ['placed on IL ', ' sprained right knee']
# ['placed on IR ', ' cervical spasms']
# ['placed on IL ', ' right knee tendinitis / bruised left quadriceps']
# ['placed on IL ', ' insomnia']
# ['placed on IL ', ' right knee patellar tendinitis']
# ['placed on IL ', ' strained left calf']
# ['placed on IL ', ' strained right calf']
# ['placed on IL ', ' left knee patella tendinitis']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' strained left knee']
# ['placed on IL ', ' strained groin']
# ['placed on IL']
# ['placed on IL ', ' bruised left quadricep']
# ['placed on IR ', ' cartilage damage in left knee']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' back spasms']
# ['placed on IR ', ' partially torn right hamstring']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' sprained right knee']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' back spasms']
# ['placed on IR ', ' sore right foot']
# ['placed on IL ', ' strained left calf']
# ['placed on IL ', ' sprained MCL in left knee']
# ['placed on IL ', ' left patella tendinitis']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sore left knee']
# ['placed on IL ', ' tendinitis in both knees']
# ['placed on IL ', ' fractured left fibula']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' plantar fasciatis in left foot']
# ['placed on IR ', ' torn cartilage in left shoulder']
# ['placed on IL ', ' strained left calf']
# ['placed on IR ', ' sore right elbow']
# ['placed on IL ', ' strained left quadriceps']
# ['placed on IR ', ' lacerated right pinky finger']
# ['placed on IR ', ' strained calf']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IR ', ' partially torn ligament in right thumb']
# ['placed on IR ', ' dislocated right finger & hyperextended right knee']
# ['placed on IL ', ' right knee injury']
# ['placed on IL ', ' lower back pain']
# ['placed on IL ', ' plantar fasciatis in right foot']
# ['placed on IL ', ' turf toe in left foot']
# ['placed on IR ', ' tendinitis in right hand / wrist injury']
# ['torn right hamstring (DNP)']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IR ', ' strength deficit in left leg']
# ['placed on IR ', ' partially collapsed lung']
# ['placed on IL ', ' sprained left knee']
# ['strained left hamstring (DNP)']
# ['placed on IR ', ' broken right leg']
# ['placed on IR ', ' kidney stones']
# ['placed on IL ', ' fractured rib']
# ['placed on IL ', ' left Achilles tendinitis']
# ['placed on IL ', ' bone spurs in left ankle']
# ['placed on IL ', ' patella tendinitis in right knee']
# ['placed on IR ', ' broken leg (out for season) (per Stats)']
# ['placed on IL ', ' strained left knee']
# ['placed on IL ', ' torn cartilage in right knee']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IR ', ' back pain']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' lower back spasms']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR ', ' sprained right MCL']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' plantar fasciatis in left foot']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' bruised right shin (date 04-19 per AP)']
# ['placed on IR ', ' torn ligaments in left shoulder (out for season)']
# ['placed on IL']
# ['placed on IL ', ' strained right hamstring']
# ['placed on IL ', ' right knee patella tendinitis']
# ['placed on IR ', ' surgery on left toe']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IR ', ' asthma']
# ['placed on IL ', ' strained right groin']
# ['placed on IR ', ' fractured nose']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' left knee patellar tendinitis']
# ['placed on IR ', ' fractured left hand']
# ['placed on IL ', ' broken left thumb']
# ['placed on IL ', ' strained lower back (back spasms per Stats)']
# ['placed on IR ', ' back strain']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' upper respiratory infection']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IR ', ' a deep thigh bruise']
# ['placed on IR ', ' tendinitis in right hand']
# ['placed on IL ', ' a sprained right ankle']
# ['placed on IR ', ' a deep bone bruise in right knee']
# ['placed on IL ', ' sprained left ankle (out for season)']
# ['underwent surgery on left knee to remove torn cartilage']
# ['placed on IR ', ' a right hip fracture']
# ['placed on IR ', ' a right hip pointer / slight eye fracture']
# ['placed on IR ', ' Achilles tendinitis']
# ['placed on IR ', ' a strained left knee']
# ['placed on IL']
# ['underwent surgery on right hand to repair a flexor tendon, an artery, and a nerve (out 3 months)']
# ['underwent arthroscopic surgery on left knee to remove damaged cartilage']
# ['double vision (out indefinitely)']
# ['underwent arthroscopic surgery on his left knee to repair damaged cartilage']
# ['underwent surgery on his right foot to remove a neuroma (entrapment of a nerve)']
# ['underwent minor nasal surgery to clear up sinus trouble']
# ['partial tear in MCL in right knee (out 6 weeks)']
# ['arthroscopic surgery on left knee to repair torn cartilage (out at least 2 weeks)']
# ['surgery on fractured left foot to insert screw (out indefinitely)']
# ['placed on IR ', ' left knee surgery']
# ['placed on IL ', ' shoulder surgery']
# ['placed on IR ', ' stress fracture in left ankle']
# ['placed on IL recovering from surgery on left knee']
# ['placed on IL ', ' strained right hamstring']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IR ', ' injured left foot']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' arthroscopic surgery on left knee']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sprained left wrist']
# ['placed on IR ', ' back strain']
# ['placed on IL ', ' sprained left knee']
# ['placed on IL ', ' sore left foot']
# ['placed on IL ', ' stress fracture in right foot']
# ['placed on IL ', ' hip pointer']
# ['placed on IR ', ' injured toe']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' sprained left knee']
# ['placed on IL ', ' strained left hamstring']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR recovering from auto accident injuries (fractured shoulder and collapsed lung)']
# ['placed on IL ', ' torn cartilage in right knee']
# ['placed on IL ', ' broken left hand']
# ['placed on IR ', ' recovery from arthroscopic surgery on left knee']
# ['placed on IL ', ' strained back']
# ['placed on IL ', ' knee tendinitis']
# ['placed on IL ', ' sore right knee']
# ['placed on IR ', ' pinched nerve in neck']
# ['placed on IR ', ' Achilles tendinitis / partially torn Achilles']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' fractured right hand']
# ['placed on IL ', ' sore left knee']
# ['placed on IL ', ' sprained ligament in right knee']
# ['placed on IR ', ' back strain']
# ['placed on IR ', ' Achilles tendinitis']
# ['placed on IL ', ' strained lower back']
# ['placed on IR ', ' partially torn left hamstring']
# ['placed on IL ', ' sore back']
# ['placed on IR ', ' back strain']
# ['placed on IL ', ' surgery on right knee / broken right leg (Stats) (out at least 2 months)']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' foot injury']
# ['placed on IR ', ' fractured left wrist']
# ['placed on IL ', ' knee tendinitis']
# ['placed on IL ', ' back spasms']
# ['placed on IR ', ' recovery from left knee surgery']
# ['placed on IL ', ' knee tendinitis']
# ['placed on IR ', ' chronic tendinitis in left knee']
# ['placed on IL ', ' plantar fasciatis in right foot']
# ['placed on IR ', ' collateral ligament tear in right index finger']
# ['placed on IL ', ' patella tendinitis in right knee']
# ['placed on IR ', ' strained back']
# ['placed on IL ', ' sprained ankle']
# ['placed on IR ', ' kidney transplant']
# ['placed on IR ', ' arthroscopic left knee surgery']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IR ', ' right tricep strain']
# ['placed on IR ', ' torn right knee ligaments']
# ['placed on IL ', ' knee tendinitis']
# ['placed on IL ', ' knee tendinitis']
# ['placed on IL ', ' plantar fasciatis in right heel']
# ['placed on IR recovery from knee surgery']
# ['placed on IL ', ' torn legament in left knee (back surgery per Stats)']
# ['placed on IL ', ' strained lower back']
# ['placed on IR ', ' left knee tendintis']
# ['placed on IR ', ' torn ligament in right ring finger']
# ['placed on IL ', ' bruised right thigh']
# ['placed on IL ', ' strained groin']
# ['placed on IL ', ' sprained toe']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' right Achilles tendinitis']
# ['placed on IR ', ' sprained finger']
# ['strained left hamstring (DNP)']
# ['placed on IR ', ' patella tendinitis in left knee']
# ['placed on IL ', ' left knee patellar tendinitis']
# ['placed on IR ', ' left Achilles tendon strain']
# ['placed on IR ', ' small tear in right quadricep (strained tendon in right knee per Stats, right quad tendon strain per Bulls media guide)']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IR ', ' strained back']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' sprained left knee']
# ['placed on IL ', ' left knee patella tendinitis']
# ['placed on IL ', ' bone bruise in left foot']
# ['placed on IL ', ' sprained right wrist']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' right patella tendinitis']
# ['placed on IL ', ' left knee patellar tendinitis']
# ['placed on IR ', ' pinched nerve in lower back']
# ['placed on IR ', ' groin strain (out 3-4 weeks)']
# ['placed on IL ', ' plantar fasciatis in right foot']
# ['placed on IR ', ' bruised cartilage in right knee']
# ['placed on IR ', ' jammed right knee']
# ['placed on IL ', ' bruised right knee']
# ['placed on IL ', ' sprained left shoulder']
# ['placed on IL ', ' deep right thigh bruise']
# ['placed on IL ', ' right foot injury / strained back (Stats)']
# ['placed on IR ', ' right thumb injury']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' left knee patella tendinitis']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' strained lower back']
# ['placed on IR ', ' sprained shoulder (per Stats)']
# ['placed on IR ', ' pulled right hamstring']
# ['placed on IL ', ' strained left hip flexor']
# ['placed on IR ', ' severe left ankle sprain (out 2 weeks)']
# ['placed on IR ', ' a groin injury']
# ['placed on IR ', ' medial gastroc tear in left calf']
# ['placed on IR left knee surgery to repair tear in lateral and medial memiscus (out 8 weeks)']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR ', ' left knee synovititis']
# ['placed on IL ', ' strained left calf']
# ['placed on IL ', ' strained left groin']
# ['placed on IL ', ' left Achilles tendinitis']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IR ', ' dislocated left shoulder']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' bruised lower back (back spasms per Stats)']
# ['placed on IL ', ' plantar fasciaitis in right foot']
# ['placed on IL ', ' strained left calf']
# ['placed on IR ', ' torn MCL in left elbow (out 3-4 weeks)']
# ['placed on IR ', ' left shoulder surgery']
# ['placed on IR ', ' sprained right ankle']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IR ', ' strained left heel']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' sore left ankle']
# ['placed on IL ', ' bruised and strained right knee']
# ['placed on IL ', ' right knee inflammation']
# ['placed on IL ', ' strained left quadricep tendon']
# ['placed on IL ', ' strained right groin']
# ['placed on IL ', ' right knee patella tendinitis']
# ['placed on IL ', ' right knee injury (out for season)']
# ['placed on IL ', ' right knee surgery']
# ['placed on IR ', ' rehab from right knee surgery']
# ['placed on IL ', ' plantar fasciatis in left foot']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' bone spurs in right ankle']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' strained left knee / loose bodies in left knee']
# ['placed on IL ', ' sprained right knee']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR ', ' bruised lower back']
# ['placed on IL ', ' sprained right wrist']
# ['placed on IR ', ' dehydration & allergic reaction']
# ['placed on IR ', ' left elbow tendinitis']
# ['placed on IL ', ' bilateral patella tendinitis']
# ['placed on IL ', ' sprained toe']
# ['placed on IR ', ' torn ligament in right hand']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' knee injury']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' sore right knee']
# ['placed on IR ', ' stress fracture of fibula in left leg']
# ['placed on IL ', ' strained left groin']
# ['placed on IL ', ' plantar fasciaitis in right foot']
# ['placed on IL ', ' left knee patellar tendinitis']
# ['placed on IR for left knee rehabilitation']
# ['placed on IR ', ' injured hamstring']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sprained back']
# ['placed on IL ', ' left quadriceps tendinitis / sprained ankle (Stats)']
# ['placed on IL ', ' strained lower back']
# ['placed on IR ', ' left knee strain']
# ['placed on IL ', ' sprained lower back']
# ['placed on IL ', ' strained right rotator cuff']
# ['placed on IR ', ' sprained right elbow']
# ['placed on IR ', ' torn ligaments in left thumb']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' back spasms']
# ['placed on IR ', ' sprained ACL in right knee']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IR ', ' left ankle sprain']
# ['placed on IL ', " jumper's knee"]
# ['placed on IL ', ' left knee patella tendinitis']
# ['placed on IR ', ' lsurgery on eft shoulder (out for season)']
# ['placed on IL ', ' fractured right pinky']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' torn meniscus cartilage in left knee']
# ['placed on IL']
# ['placed on IR ', ' torn MCL in right elbow']
# ['placed on IL ', ' left knee inflammation']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' strained lower back']
# ['placed on IR ', ' tendinitis in right quadriceps']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' left knee injury']
# ['placed on IL']
# ['placed on IL ', ' plantar fasciatis of the left heel']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR ', ' bruised bone in right knee']
# ['placed on IL ', ' strained left calf']
# ['placed on IL ', ' fluid in right knee']
# ['placed on IL ', ' strained right Achilles tendon']
# ['placed on IR ', ' lower abdominal strain']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' bruised right quadriceps']
# ['placed on IR ', ' synovitis in right knee']
# ['placed on IL ', ' lower back spasms']
# ['placed on IL ', ' sore right knee']
# ['placed on IR ', ' right thumb injury']
# ['placed on IL ', ' torn cartilage in left knee']
# ['placed on IR ', ' plantar faciatis']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sprained right thumb']
# ['placed on IL ', ' left patella tendinitis']
# ['placed on IL ', ' upper respiratory infection']
# ['placed on IL ', ' tendinitis in both knees']
# ['placed on IL ', ' right shoulder tendinitis']
# ['placed on IR ', ' torn right calf muscle']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IR ', ' damaged facial nerve']
# ['placed on IR ', ' persistent weight loss & dehydration']
# ['placed on IR ', ' strained back']
# ['placed on IL ', ' strained right calf']
# ['placed on IR ', ' respiratory problems']
# ['placed on IL ', ' wrist injury (out for season)']
# ['placed on IR ', ' low back strain']
# ['placed on IL ', ' strained left quadriceps']
# ['placed on IL ', ' sprained MCL in right knee']
# ['placed on IL ', ' sprained right foot']
# ['placed on IL ', ' broken left ring finger']
# ['placed on IL ', ' broken left ankle']
# ['placed on IL ', ' sprained left wrist']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IR ', ' irritated nerve in neck']
# ['placed on IR witih left patellar tendinitis']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' left knee patella tendinitis']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' sore lower back']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sore back']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR ', ' inflamed right elbow and broken right toe']
# ['placed on IL ', ' lower back spasms']
# ['placed on IL ', ' right knee inflammation']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' strained right calf']
# ['placed on IR ', ' bone spur in right ankle']
# ['placed on IR ', ' dislocated right index finger']
# ['placed on IR ', ' right shoulder inflammation & broken left toe']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IR ', ' injured hamstring']
# ['placed on IL ', ' sprained left foot']
# ['placed on IL ', ' sprained right knee']
# ['placed on IL ', ' bone bruise in left foot/ankle']
# ['placed on IL']
# ['placed on IL']
# ['placed on IL ', ' flu']
# ['placed on IL ', ' strained right calf']
# ['placed on IL ', ' sore left knee']
# ['placed on IR ', ' bone spur in right / left (P) foot']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' bruised right thigh']
# ['placed on IL ', ' bone spurs in right ankle']
# ['placed on IL ', ' torn ACL in left knee (out for season)']
# ['placed on IR ', ' recovery from left knee surgery']
# ['placed on IR ', ' recovery from left knee surgery']
# ['placed on IR ', ' pinched nerve in neck (player had not officially submitted retirement papers)']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' lower back spasms']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' sore left shoulder / right shoulder tendinitis (per Bulls media guide)']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' left foot tendinitis']
# ['placed on IR ', ' surgery on right patella']
# ['placed on IL ', ' patellar tendinitis in both knees']
# ['placed on IL ', ' patellar tendinitis in both knees']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR ', ' fractured right hip']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' bruised right knee']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' strained right shoulder']
# ['placed on IL ', ' sprained MCL in right knee']
# ['placed on IR ', ' malaria']
# ['placed on IR ', ' a stress fracture in left foot']
# ['placed on IR ', ' bruised knee & calf']
# ['placed on IL ', ' stress fracture in right foot']
# ['placed on IL ', ' right ankle tendinitis (right knee tendinitis per E)']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IR ', ' recovery from right knee surgery']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' patella tendinitis']
# ['placed on IL ', ' right knee patella tendinitis']
# ['placed on IR ', ' chondromalacia, right knee']
# ['placed on IL ', ' lower back pain']
# ['placed on IL ', ' stress fracture in right foot']
# ['placed on IL ', ' strained right shoulder']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IR ', ' ruptured tendon in left (right?) knee']
# ['placed on IR ', ' bruised elbow']
# ['placed on IL ', ' sprained big toe']
# ['placed on IR ', ' strained left abductor muscle']
# ['placed on IL ', ' left Achilles tendon injury']
# ['placed on IL ', ' right knee surgery']
# ['placed on IL ', ' strained groin']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR ', ' degenerative arthritis in left knee']
# ['placed on IL ', ' patellar tendinitis in both knees']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' strained right elbow']
# ['placed on IR ', ' recovery from back surgery']
# ['placed on IR ', ' strained rib cage muscles']
# ['placed on IL recovering from surgery on knee']
# ['placed on IL ', ' bilateral medial tibial periositis (shin splints)']
# ['placed on IL ', ' sore left knee']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IR ', ' left shoulder impingement']
# ['placed on IR ', ' plantar fasciaitis in left foot']
# ['placed on IL ', ' left patella tendinitis']
# ['placed on IL ', ' left knee injury']
# ['placed on IR ', ' thumb & knee injuries']
# ['placed on IL ', ' torn ACL in left knee']
# ['placed on IL ', ' right knee injury']
# ['placed on IL ', ' hyperextended left knee']
# ['placed on IL ', ' herniated disc in back']
# ['placed on IL ', ' strained right hamstring']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' left patella tendinitis']
# ['placed on IL ', ' strained left hamstring']
# ['placed on IR ', ' facial injury / broken jaw']
# ['placed on IL ', ' sore left ankle']
# ['placed on IL ', ' fractured left index finger']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR recovering from left foot surgery']
# ['placed on IL ', ' strained right ankle']
# ['placed on IL ', ' groin injury']
# ['placed on IL recovering from surgery on right knee']
# ['placed on IL ', ' broken right hand']
# ['placed on IL ', ' lower back spasms']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' bruised right elbow']
# ['placed on IR ', ' adjustment disorder due to death of mother']
# ['placed on IR ', ' sore right foot']
# ['placed on IL ', ' strained left foot']
# ['placed on IL ', ' lower back spasms']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' left knee patella tendinitis']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IR ', ' poor conditioning / heart medication']
# ['placed on IL ', ' bruised ribs']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' strained right hip flexor']
# ['placed on IL ', ' plantar fasciatis in left foot']
# ['placed on IL ', ' left knee inflammation']
# ['placed on IL ', ' sore lower back']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sprained MCL in right knee']
# ['placed on IR recovering from surgery on right knee']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' bruised right knee']
# ['placed on IL ', ' sprained ankle']
# ['placed on IL ', ' sprained right knee']
# ['placed on IR ', ' bursitis in left hip']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IR ', ' peritonsillar abcess']
# ['placed on IL ', ' right Achilles tendinitis']
# ['placed on IR ', ' partially torn MCL in left knee']
# ['placed on IL ', ' fractured left thumb']
# ['placed on IL ', ' knee injury']
# ['placed on IL ', ' back spasms']
# ['placed on IR ', ' inflammation and cartilage damage in left knee']
# ['placed on IL ', ' sprained right foot']
# ['placed on IL ', ' sprained lower back']
# ['placed on IL ', ' surgery on right knee']
# ['placed on IR ', ' stress fracture of right ankle']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' sprained left ankle and sore right big toe']
# ['placed on IR ', ' right ankle inflammation']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' bruised left quadriceps & sore left hamstring']
# ['placed on IL ', ' left patella tendinitis']
# ['placed on IL ', ' strained right groin']
# ['placed on IL ', ' left foot tendinitis']
# ['placed on IR ', ' high right ankle sprain']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' sprained right knee']
# ['placed on IL ', ' sprained left knee']
# ['placed on IL ', ' hyperextended left knee']
# ['placed on IL ', ' strained right groin']
# ['placed on IR ', ' chip fracture in right ankle']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' sprained left shoulder']
# ['placed on IR ', ' sore throat & ear infection']
# ['placed on IL ', ' broken left hand']
# ['placed on IR ', ' bilateral synovitis']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IR ', ' peritonsillar abcess in throat']
# ['placed on IL ', ' strained right groin']
# ['placed on IR ', ' bursitis in left hip']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IR ', ' sruised ulnar nerve in right elbow']
# ['placed on IL ', ' strained right groin']
# ['placed on IR ', ' stress fracture of lavicular bone in left foot']
# ['placed on IL ', ' broken left ankle (out for season)']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' tendinitis in both knees']
# ['placed on IR ', ' broken right thumb']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IR ', ' tendinitis in right / left (P) quadricep']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' tendinitis in both knees']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' viral syndrome']
# ['placed on IL ', ' plantar fasciatis in right foot']
# ['placed on IL recovering from surgery on left knee']
# ['placed on IL ', ' strained right shoulder']
# ['placed on IR ', ' swollen right knee']
# ['placed on IR ', ' small tear in right rotator cuff']
# ['placed on IL ', ' sore lower back']
# ['placed on IL ', ' strained right knee']
# ['placed on IL ', ' strained left hamstring']
# ['placed on IL ', ' plantar fasciatis in left foot']
# ['placed on IL ', ' acute inflammation of soft tissue and soreness in left knee']
# ['placed on IR ', ' a strained right hand']
# ['placed on IR ', ' broken finger on right hand (out 2 months)']
# ['placed on IR ', ' strained back']
# ['placed on IL ', ' right Achilles tendinitis']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IR ', ' right knee effusion (soreness)']
# ['placed on IR recovering from left ankle surgery']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' strained right groin']
# ['placed on IL ', ' partially torn left rotator cuff']
# ['placed on IL ', ' sore left knee']
# ['placed on IR ', ' right elbow tendinitis']
# ['placed on IR ', ' strained right deltoid muscle']
# ['placed on IR ', ' right elbow tendinitis']
# ['placed on IL ', ' sprained right wrist']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' strained right groin']
# ['placed on IR ', ' bronchitis']
# ['placed on IL ', ' left knee patella tendinitis']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' broken left hand (out 4-6 weeks)']
# ['placed on IL ', ' lower back spasms']
# ['placed on IL ', ' fractured right wrist']
# ['placed on IR ', ' sore right hip (DNP)']
# ['placed on IR ', ' a strained right hand']
# ['placed on IR ', " shooter's elbow"]
# ['placed on IL ', ' left knee patellar tendinitis']
# ['placed on IL ', ' hyperextended left knee']
# ['placed on IL ', ' knee injury']
# ['placed on IL ', ' strained left calf']
# ['placed on IR ', ' quadriceps tendinitis']
# ['placed on IL ', ' lower back spasms']
# ['placed on IL ', ' sore left knee']
# ['placed on IL ', ' surgery on left knee (out 2-3 weeks)']
# ['placed on IL ', ' patella tendinitis']
# ['placed on IL ', ' strained left hamstring']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' sore hamstrings']
# ['placed on IL ', ' a stress fracture in right wrist']
# ['placed on IR ', ' left elbow tendinitis']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' strained groin']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sprained right (left?) ankle']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' sprained right wrist']
# ['placed on IR ', ' stress fracture in back']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' foot injury']
# ['placed on IL ', ' left ankle tendinitis']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' plantar fasciatis in right foot']
# ['placed on IL ', ' sore right shoulder']
# ['placed on IR ', ' right knee osteoarthritis']
# ['placed on IL ', ' patella tendinitis in both knees']
# ['placed on IL ', ' strained right calf']
# ['placed on IR ', ' sprained left ankle / sore back']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' left leg injury']
# ['placed on IR ', ' dislocated left shoulder']
# ['placed on IL ', ' strained left groin']
# ['placed on IL']
# ['placed on IL ', ' a sprained right thumb']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' broken left thumb']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' strained right shoulder']
# ['placed on IL ', ' sprained right wrist']
# ['placed on IR ', ' blood clot in left leg']
# ['placed on IL ', ' sore left knee']
# ['placed on IR ', ' fractured left hand']
# ['placed on IL ', ' strained left groin']
# ['placed on IL ', ' lower back spasms']
# ['placed on IR ', ' sprained finger']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' lower back spasms']
# ['placed on IR ', ' sprained left toe']
# ['placed on IR ', ' sore left Achilles tendon']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR ', ' dislocated right thumb']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR ', ' plantar fasciitis in left foot']
# ['placed on IR ', ' right foot plantar fascia strain (torn per Bulls media guide)']
# ['placed on IR ', ' left knee/quadriceps tendinitis']
# ['placed on IR ', ' strained right deltoid muscle (sprained right ankle per P)']
# ['placed on IR ', ' sore right foot']
# ['placed on IL ', ' sprained left thumb']
# ['placed on IR ', ' sprained left ankle (sprained right ankle per Bulls media guide)']
# ['placed on IL ', ' strained left groin']
# ['placed on IR ', ' right infrapatella tendonitis']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' strained left calf']
# ['placed on IL ', ' right knee patella tendinitis']
# ['placed on IR ', ' sore left & right Achilles tendon']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IR, player checked into drug rehab program for cocaine abuse']
# ['placed on IR ', ' dislocated left kneecap']
# ['placed on IL ', ' left Achilles tendinitis']
# ['placed on IL ', ' right knee patella tendinitis']
# ['placed on IR ', ' a right adductor strain']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' torn ACL in left knee (out for season)']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' strained right groin']
# ['placed on IL ', ' hyperextended left knee']
# ['placed on IR ', ' right shoulder subluxation']
# ['placed on IL ', ' bruised left foot']
# ['placed on IL ', ' bruised right foot']
# ['placed on IL ', ' strained right groin']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' strained right hip flexor']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR ', ' sprained left fifth toe']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' strained left groin']
# ['placed on IL ', ' bruised left hip']
# ['placed on IL ', ' bruised left calf']
# ['placed on IL ', ' broken left thumb']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IR ', ' right shoulder rotator cuff weakness']
# ['placed on IL ', ' left knee/quadricaps tendinitis']
# ['placed on IR ', ' sprained left metatarsal']
# ['placed on IL recovering from surgery on right knee']
# ['placed on IR ', ' non-acute fracture of left big toe']
# ['placed on IL ', ' torn ACL in left knee']
# ['placed on IL recovering from surgery on right ring finger']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' back spasms']
# ['placed on IL recovering from surgery on left foot (out until mid-Dec)']
# ['placed on IR ', ' pulled/strained right groin']
# ['placed on IR ', ' nerve damage in left leg']
# ['placed on IR ', ' bruised left shin']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' back injury']
# ['placed on IL ', ' right knee inflammation']
# ['placed on IR ', ' dislocated/jammed right thumb']
# ['placed on IR ', ' surgery on left foot']
# ['placed on IL ', ' back spasms / left knee tendinitis (P)']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' right knee patella tendinitis']
# ['placed on IL ', ' plantar fasciatis in left foot']
# ['placed on IL ', ' fractured right foot']
# ['placed on IR ', ' injured knee / surgery on left wrist (P)']
# ['placed on IL ', ' abdominal strain / right knee tendinitis (P)']
# ['placed on IL ', ' right knee patella tendinitis']
# ['placed on IL ', ' chip fracture in right foot']
# ['placed on IL ', ' broken right hand']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' broken right foot']
# ['placed on IL']
# ['placed on IR recovering from knee surgery']
# ['placed on IL ', ' sprained left knee']
# ['placed on IR ', ' sprained thumb']
# ['placed on IL ', ' sprained right toe']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' strained left hamstring']
# ['placed on IL ', ' lower back injury']
# ['placed on IL ', ' sore left knee']
# ['placed on IL ', ' medial tibial periostitis']
# ['placed on IL ', ' torn right Achilles tendon']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR ', ' fractured left ring finger']
# ['placed on IL']
# ['placed on IL']
# ['placed on IL ', ' fractured right ring finger']
# ['placed on IL ', ' plantar fasciatis']
# ['placed on IL ', ' foot injury']
# ['placed on IL ', ' leg injury']
# ['placed on IL ', ' knee injury']
# ['placed on IL ', ' knee injury']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' strained right hamstring']
# ['placed on IL ', ' torn ligament in left thumb']
# ['placed on IR ', ' torn right hamstring']
# ['placed on IL ', ' lower back spasms']
# ['placed on IL ', ' lower back spasms']
# ['placed on IR ', ' a strained left / right (P) quadriceps']
# ['placed on IR ', ' right hip flexor injury']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' patella femoral arthritis in both knees']
# ['placed on IL ', ' strained right abductor']
# ['placed on IL ', ' strained right hamstring']
# ['placed on IL ', ' left ankle tendinitis']
# ['placed on IL ', ' sprained left knee']
# ['placed on IR ', ' fractured left pinky']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IL ', ' a torn ACL in left knee']
# ['placed on IL ', ' bruised right knee']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' bruised right knee']
# ['placed on IL ', ' high left ankle sprain (out 4-6 weeks)']
# ['placed on IR ', ' bone bruise in right instep']
# ['placed on IL ', ' sprained ligaments in right hand']
# ['placed on IR ', ' lower left leg nerve damage']
# ['placed on IL ', ' strained groin']
# ['placed on IL ', ' strained right hamstring']
# ['placed on IL ', ' plantar fasciatis in left foot']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IR ', ' jammed right thumb']
# ['placed on IL ', ' pulled right groin']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' sprained right foot']
# ['placed on IR ', ' left toe sesamoiditis']
# ['placed on IL ', ' sprained right wrist']
# ['placed on IL ', ' patella tendinitis']
# ['placed on IL ', ' partially torn peroneal tendon in right foot']
# ['placed on IL ', ' bruised right clavicle']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' right Achilles tendinitis']
# ['placed on IL ', ' surgery on left knee']
# ['placed on IL ', ' bone bruise in right foot']
# ['placed on IL ', ' right knee patella tendinitis']
# ['placed on IL ', ' right knee patella tendinitis']
# ['placed on IL ', ' knee tendinitis']
# ['placed on IL ', ' sprained left big toe']
# ['placed on IL ', ' sore left knee']
# ['placed on IL ', ' plantar fasciatis in left foot (out 4-6 weeks)']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' left knee patella tendinitis']
# ['placed on IL ', ' upper respiratory infection']
# ['placed on IL ', ' bruised ribs']
# ['placed on IL ', ' right knee tendinitis']
# ['placed on IR ', ' left knee/quadricep tendinitis']
# ['placed on IL ', ' strained left shoulder']
# ['placed on IR ', ' bruised/sprained right knee']
# ['placed on IL ', ' a sprained right ankle']
# ['placed on IR ', ' fractured left knee (out 1-2 months)']
# ['placed on IL ', ' strained right groin']
# ['placed on IR ', ' sprained/sore left foot']
# ['placed on IL ', ' right Achilles tendinitis']
# ['placed on IL ', ' right Achilles tendinitis']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' bruised left shin and sprained left ankle']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' bruised left hip']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' bruised right knee']
# ['placed on IR ', ' fractured left leg']
# ['placed on IR ', ' right shoulder rotator cuff weakness']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' lower back spasms']
# ['placed on IR ', ' cervican strain']
# ['placed on IR ', ' strained patellar tendon in right knee']
# ['placed on IR ', ' synovitis / loose body in left knee']
# ['placed on IL ', ' strained left hamstring']
# ['placed on IR ', ' bruised left shin']
# ['placed on IR ', ' sore right ankle']
# ['placed on IL ', ' abdominal strain']
# ['placed on IL ', ' left Achilles tendinitis']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' plantar fasciatis in right foot']
# ['placed on IR ', ' sore left toe / right big toe (P)']
# ['placed on IL ', ' left ankle tendinitis']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' strained lower back']
# ['placed on IL ', ' sprained left knee']
# ['placed on IR ', ' posterior tibialis tendinitis in left knee']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' bone bruise in right knee']
# ['placed on IL']
# ['placed on IL ', ' left knee tendinitis']
# ['placed on IL ', ' lower back pain']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' bone bruise in right foot']
# ['placed on IL ', ' right knee patella tendinitis']
# ['placed on IL ', ' broken right index finger (out 6-8 weeks)']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IR ', ' right calf / Achilles tendinitis']
# ['placed on IL ', ' strained left hamstring']
# ['placed on IL ', ' left quadriceps tendinitis']
# ['placed on IL ', ' a torn ACL in left knee']
# ['placed on IL ', ' strained right groin']
# ['placed on IL ', ' left quadriceps tendinitis']
# ['placed on IR ', ' broken right middle finger']
# ['placed on IL ', ' bruised right knee']
# ['placed on IR ', ' high left ankle sprain']
# ['placed on IL ', ' sprained left ankle']
# ...
# ['placed on IL ', ' fractured fibula in left leg']
# ['placed on IL ', ' bruised left shin']
# ['placed on IL ', ' illness']
# ['placed on IL']
# ['placed on IL ', ' sore right knee']
# ['placed on IL']
# ['placed on IL']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' sore lower back']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' illness']
# ['placed on IL']
# ['placed on IL ', ' right calf injury']
# ['placed on IL ', ' left knee injury']
# ['placed on IL']
# ['placed on IL ', ' sore left knee']
# ['placed on IL ', ' left hamstring injury']
# ['placed on IL ', ' sprained right wrist']
# ['placed on IL ', ' throat injury']
# ['placed on IL ', ' back injury']
# ['placed on IL ', ' right shoulder injury']
# ['placed on IL ', ' right leg injury']
# ['placed on IL']
# ['placed on IL ', ' illness']
# ['placed on IL']
# ['placed on IL ', ' bruised right thigh']
# ['placed on IL ', ' illness']
# ['placed on IL']
# ['placed on IL ', ' fractured nose']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' sprained left knee']
# ['placed on IL ', ' right shoulder injury']
# ['placed on IL ', ' sprained right shoulder']
# ['placed on IL ', ' sore neck']
# ['placed on IL ', ' right calf injury']
# ['placed on IL ', ' left knee injury']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' high right ankle sprain']
# ['placed on IL ', ' strained left calf']
# ['placed on IL ', ' bruised left knee']
# ['placed on IL']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' left hand injury']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' strained left hamstring']
# ['placed on IL ', ' bruised lower back (out for season)']
# ['placed on IL']
# ['placed on IL ', ' bruised tailbone']
# ['placed on IL ', ' right calf injury']
# ['placed on IL ', ' bruised right knee']
# ['placed on IL ', ' left hamstring injury']
# ['strep throat (already on IL)']
# ['placed on IL ', ' right hip injury']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' sore lower back']
# ['placed on IL ', ' right heel injury']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' groin injury']
# ['placed on IL ', ' vestibular condition']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' fractured finger']
# ['placed on IL']
# ['placed on IL ', ' sore lower back']
# ['placed on IL ', ' bruised right knee']
# ['placed on IL ', ' left hamstring injury']
# ['placed on IL for personal reasons']
# ['placed on IL']
# ['placed on IL ', ' left knee injury']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' left knee injury']
# ['placed on IL ', ' strained right adductor']
# ['placed on IL ', ' sprained right thumb']
# ['placed on IL ', ' sore neck']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' concussion']
# ['placed on IL ', ' concussion']
# ['placed on IL ', ' right thumb injury']
# ['placed on IL ', ' sore left knee']
# ['placed on IL']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' bruised right knee']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' sore lower back']
# ['placed on IL ', ' sore left knee']
# ['placed on IL ', ' sore lower back']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' finger injury']
# ['placed on IL ', ' sore lower back']
# ['placed on IL ', ' strained right hamstring']
# ['placed on IL ', ' sprained right thumb']
# ['placed on IL ', ' illness']
# ['placed on IL']
# ['placed on IL ', ' right hamstring injury']
# ['placed on IL ', ' left hamstring injury']
# ['placed on IL']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL']
# ['placed on IL ', ' right groin injury']
# ['placed on IL ', ' sprained left foot (out for season)']
# ['placed on IL ', ' torn right Achilles tendon (out for season)']
# ['placed on IL ', ' right foot injury']
# ['placed on IL ', ' left knee injury (out for season)']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' flu']
# ['placed on IL ', ' left shoulder injury']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' stress reaction in pelvis']
# ['placed on IL ', ' bruised right hip']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' concussion']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' fractured nose']
# ['placed on IL ', ' right hand injury']
# ['placed on IL ', ' strained left hamstring']
# ['placed on IL ', ' sore right ankle']
# ['placed on IL ', ' left thumb injury']
# ['placed on IL ', ' surgery to repair fractured left cheekbone']
# ['placed on IL ', ' right hip flexor injury']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sore left hand']
# ['placed on IL ', ' sore left knee']
# ['placed on IL']
# ['placed on IL']
# ['placed on IL ', ' sprained right knee']
# ['placed on IL ', ' strained neck']
# ['placed on IL']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' strained left hamstring']
# ['placed on IL ', ' sore left hip']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' right heel injury']
# ['placed on IL ', ' sore left knee']
# ['placed on IL ', ' right elbow injury']
# ['placed on IL']
# ['placed on IL']
# ['placed on IL ', ' flu']
# ['placed on IL ', ' sprained MCL in right knee (out for season)']
# ['placed on IL ', ' right ankle injury']
# ['placed on IL ', ' fractured left hand']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' left calf injury']
# ['placed on IL ', ' right quadricep injury']
# ['placed on IL ', ' bruised right thigh']
# ['placed on IL']
# ['placed on IL ', ' concussion']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' left knee injury']
# ['placed on IL ', ' sprained right knee (out for season)']
# ['placed on IL ', ' concussion']
# ['placed on IL ', ' left hip injury']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' sprained left thumb']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sore right ankle']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sore left shoulder']
# ['placed on IL']
# ['placed on IL']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' sore left foot']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL']
# ['placed on IL ', ' back spasms']
# ['placed on IL']
# ['placed on IL']
# ['placed on IL ', ' sore right foot']
# ['placed on IL ', ' right groin injury']
# ['placed on IL ', ' concussion']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' neck injury']
# ['placed on IL ', ' bruised right quadriceps']
# ['placed on IL ', ' left knee injury (out for season)']
# ['placed on IL ', ' left hamstring injury']
# ['placed on IL ', ' strained right shoulder']
# ['placed on IL ', ' bruised left leg']
# ['placed on IL']
# ['placed on IL']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' sore left hip']
# ['placed on IL']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' right knee injury']
# ['placed on IL ', ' sore back']
# ['placed on IL ', ' sore right Achilles']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' fractured left wrist (out for season)']
# ['placed on IL ', ' left calf injury']
# ['placed on IL']
# ['placed on IL ', ' left foot injury']
# ['placed on IL']
# ['placed on IL']
# ['placed on IL ', ' flu']
# ['placed on IL']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' strained left hamstring']
# ['placed on IL for personal reasons']
# ['placed on IL ', ' abdominal injury']
# ['placed on IL ', ' sore right ankle']
# ['placed on IL']
# ['placed on IL ', ' sore lower back']
# ['placed on IL ', ' back injury']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' sore back']
# ['placed on IL']
# ['placed on IL ', ' sprained left knee']
# ['placed on IL ', ' groin injury']
# ['placed on IL ', ' torn labrum in right shoulder (out for season)']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' right shoulder injury (out for season)']
# ['placed on IL ', ' torn ACL in left knee (out for season)']
# ['placed on IL ', ' strained left calf']
# ['placed on IL ', ' sprained left ankle (out for season)']
# ['placed on IL ', ' right elbow injury']
# ['placed on IL ', ' strained right shoulder']
# ['placed on IL ', ' sprained left shoulder']
# ['placed on IL ', ' abdominal injury']
# ['placed on IL ', ' left groin injury']
# ['placed on IL']
# ['placed on IL ', ' sore neck']
# ['placed on IL ', ' right quadricep injury']
# ['placed on IL']
# ['placed on IL ', ' right ankle injury']
# ['placed on IL ', ' left shoulder injury']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' sore left ankle']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' concussion']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' right hip injury']
# ['placed on IL ', ' strained left groin (out for season)']
# ['placed on IL ', ' sprained left thumb']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL']
# ['placed on IL ', ' strained right groin']
# ['placed on IL ', ' strained left quadriceps (out for season)']
# ['placed on IL ', ' right knee inflammation']
# ['placed on IL ', ' tightness in lower back']
# ['placed on IL ', ' sprained MCL in right knee']
# ['placed on IL ', ' concussion']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' sore left ankle']
# ['placed on IL ', ' right hamstring injury']
# ['placed on IL ', ' illness']
# ['placed on IL right foot injury (out for season)']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL']
# ['placed on IL ', ' groin injury']
# ['placed on IL ', ' bruised right knee']
# ['placed on IL ', ' strained right hamstring']
# ['placed on IL ', ' left hamstring injury']
# ['placed on IL ', ' sore right ankle']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' sprained right ankle (out for season)']
# ['placed on IL ', ' concussion (out for season)']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sprained left knee']
# ['placed on IL ', ' flu']
# ['placed on IL']
# ['placed on IL ', ' sprained right elbow']
# ['placed on IL ', ' right hip injury']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' toe injury']
# ['placed on IL ', ' torn left quadriceps']
# ['placed on IL ', ' left leg injury']
# ['placed on IL']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' flu']
# ['placed on IL ', ' sprained left knee']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' fractured right wrist']
# ['placed on IL ', ' bruised right hip']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' left hamstring injury']
# ['placed on IL ', ' right adductor injury']
# ['placed on IL ', ' upset stomach']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' strained right calf']
# ['placed on IL ', ' groin injury']
# ['placed on IL ', ' left big toe injury']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' right hip injury']
# ['COVID-19 coronavirus (out for season)']
# ['COVID-19 coronavirus (out indefinitely)']
# ['placed on IL ', ' conditioning']
# ['placed on IL recovering from surgery on shoulder (out for season)']
# ['placed on IL (out for season)']
# ['placed on IL ', ' strained right hip']
# ['placed on IL ', ' fractured left foot (out for season)']
# ['placed on IL ', ' sore right knee (out for season)']
# ['placed on IL ', ' left foot injury (out for season)']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' COVID-19 coronavirus']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' left hip pointer']
# ['placed on IL']
# ['placed on IL ', ' Achilles injury']
# ['placed on IL ', ' left hamstring injury']
# ['placed on IL ', ' cervical strain']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' sore left knee (out for season)']
# ['placed on IL ', ' sprained left foot']
# ['placed on IL ', ' right calf injury']
# ['placed on IL ', ' lower leg injury']
# ['placed on IL ', ' sore right ankle']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' torn ACL in left knee (out for season)']
# ['placed on IL ', ' concussion']
# ['placed on IL ', ' strained left calf']
# ['placed on IL ', ' torn meniscus in left knee (out for season)']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' left foot injury (out for season)']
# ['placed on IL ', ' strained left hamstring (out for season)']
# ['placed on IL ', ' right knee injury / conditioning']
# ['placed on IL ', ' sprained right ankle']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' left leg injury']
# ['placed on IL ', ' right calf injury']
# ['placed on IL ', ' neck spasms']
# ['placed on IL ', ' right groin injury']
# ['placed on IL ', ' right hip injury']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' bruised right quadriceps']
# ['placed on IL ', ' left calf injury (out for season)']
# ['placed on IL ', ' strained left hamstring (out for season)']
# ['placed on IL']
# ['placed on IL ', ' bruised lower left leg']
# ['placed on IL ', ' strained left hip']
# ['placed on IL ', ' sore left knee']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' right hip injury']
# ['placed on IL ', ' bruised right foot']
# ['placed on IL ', ' illness']
# ['placed on IL ', ' left hip injury']
# ['placed on IL ', ' sore right ankle']
# ['placed on IL ', ' sprained right ankle (out for season)']
# ['placed on IL ', ' left ankle injury']
# ['placed on IL ', ' toothache']
# ['placed on IL ', ' left leg injury']
# ['placed on IL ', ' sore left shoulder (out for season)']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' sore right knee (out for season)']
# ['placed on IL ', ' right knee injury']
# ['placed on IL ', ' sore lower back']
# ['placed on IL ', ' surgery on right knee (out for season)']
# ['placed on IL ', ' bruised right knee']
# ['placed on IL ', ' left ankle injury']
# ['placed on IL ', ' sore right ankle']
# ['placed on IL ', ' right elbow injury']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' right adductor injury']
# ['placed on IL ', ' sprained left foot']
# ['placed on IL ', ' right leg injury']
# ['placed on IL ', ' sore right foot']
# ['placed on IL ', ' sore left toe']
# ['placed on IL ', ' shoulder injury']
# ['placed on IL ', ' sore left foot']
# ['placed on IL ', ' sore right foot']
# ['placed on IL ', ' sprained left ankle']
# ['placed on IL ', ' left knee injury']
# ['placed on IL ', ' throat']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' neck spasms']
# ['placed on IL ', ' sore neck']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' strained right quadriceps']
# ['placed on IL ', ' sprained right elbow']
# ['placed on IL ', ' sprained right shoulder']
# ['placed on IL ', ' sore left knee']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' bruised left heel']
# ['placed on IL ', ' sprained right wrist']
# ['placed on IL ', ' left hand injury']
# ['placed on IL ', ' sprained right knee']
# ['placed on IL ', ' sore right knee']
# ['placed on IL ', ' sore left ankle']
# ['placed on IL ', ' COVID-19 coronavirus (out for season)']
# ['placed on IL ', ' sore left ankle']
# ['placed on IL']
# ['placed on IL ', ' neck injury']
# ['placed on IL ', ' strained left oblique muscle (out for season)']
# ['placed on IL ', ' left knee injury (out for season)']
# ['placed on IL ', ' pubic bone injury, strained left groin']
# ['placed on IL ', ' strained left calf']
# ['placed on IL ', ' left knee injury']
# ['placed on IL ', ' sore lower back']
# ['placed on IL ', ' back spasms']
# ['placed on IL ', ' left Achilles injury']
# ['placed on IL ', ' torn meniscus in right knee (out for season)']
# ['placed on IL ', ' strained right hamstring']
# ['placed on IL ', ' left calf injury (out for season)']
# ['placed on IL ', ' bruised right knee']
# ['placed on IL ', ' neck spasms (out for season)']
# ['placed on IL ', ' strained right adductor (out for season)']
# ['placed on IL ', ' torn plantar fascia in left foot (out for season)']
# ['placed on IL ', ' eye injury']
# ['placed on IL ', ' right calf injury']
# ['placed on IL ', ' sore r']

# %%
nba_injury_1998.to_csv('nba_injury_1998.csv',mode='w',index=False)
